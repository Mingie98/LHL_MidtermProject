# %%
import os
import pandas as pd
import requests
from statistics import mean
import time

# %%
def find_places_and_distances(api_key, latitude, longitude, radius=1000, place_type='university'):
    results = []
    page_token = None

    while True:
        nearby_search_endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        location = f"{latitude},{longitude}"

        nearby_search_params = {
            'location': location,
            'radius': radius,
            'type': place_type,
            'key': api_key,
            'pagetoken': page_token
        }

        nearby_response = requests.get(nearby_search_endpoint, params=nearby_search_params)
        response_json = nearby_response.json()

        if response_json.get('status') != 'OK':
            print(f"Error or no results for {place_type} at location ({latitude}, {longitude}): {response_json.get('status')}")
            break

        results.extend(response_json.get('results', []))

        page_token = response_json.get('next_page_token')
        if not page_token:
            break

        time.sleep(2)  # Necessary to wait for the next page token to become valid

    return results

def calculate_distances(api_key, latitude, longitude, places):
    if not places:
        return None, None

    location = f"{latitude},{longitude}"
    max_elements_per_request = 25  # Maximum destinations per request to avoid exceeding API limits
    distances = []

    for i in range(0, len(places), max_elements_per_request):
        chunk = places[i:i + max_elements_per_request]
        destinations = [f"{place['geometry']['location']['lat']},{place['geometry']['location']['lng']}" for place in chunk]

        distance_matrix_params = {
            'origins': location,
            'destinations': '|'.join(destinations),
            'key': api_key,
            'mode': 'walking'
        }

        distance_matrix_endpoint = "https://maps.googleapis.com/maps/api/distancematrix/json"
        distance_matrix_response = requests.get(distance_matrix_endpoint, params=distance_matrix_params)
        distance_matrix_json = distance_matrix_response.json()

        if distance_matrix_json.get('status') != 'OK':
            print(f"Distance Matrix API error for location ({latitude}, {longitude}): {distance_matrix_json.get('status')}")
            return None, None

        distances.extend([element['distance']['value'] for element in distance_matrix_json['rows'][0]['elements'] if 'distance' in element])

    avg_distance = mean(distances) if distances else None
    shortest_distance = min(distances) if distances else None

    return avg_distance, shortest_distance

# Read CSV file
df = pd.read_csv('boba_shops.csv')  # Replace with your CSV file path

# Define API key
api_key = os.environ["googleplaces_api"]

# Process each bubble tea shop
results = []
for index, row in df.iterrows():
    shop_name = row['Place Name']
    shop_latitude = row['Latitude']
    shop_longitude = row['Longitude']
    shop_place_id = row['Place ID']

    universities = find_places_and_distances(api_key, shop_latitude, shop_longitude, place_type='university')
    highschools = find_places_and_distances(api_key, shop_latitude, shop_longitude, place_type='school')

    avg_distance_uni, shortest_distance_uni = calculate_distances(api_key, shop_latitude, shop_longitude, universities) if universities else (None, None)
    avg_distance_hs, shortest_distance_hs = calculate_distances(api_key, shop_latitude, shop_longitude, highschools) if highschools else (None, None)

    results.append({
        'Bubble Tea Shop': shop_name,
        'Latitude': shop_latitude,
        'Longitude': shop_longitude,
        'Place ID': shop_place_id,
        'Number of Nearby Colleges': len(universities),
        'Nearby Colleges': [uni['name'] for uni in universities] if universities else [],
        'Average Distance to Colleges (m)': avg_distance_uni,
        'Shortest Distance to Colleges (m)': shortest_distance_uni,
        'Number of Nearby Schools': len(highschools),
        'Nearby Schools': [hs['name'] for hs in highschools] if highschools else [],
        'Average Distance to Schools (m)': avg_distance_hs,
        'Shortest Distance to Schools (m)': shortest_distance_hs,
    })

# Convert results to DataFrame
results_df = pd.DataFrame(results)

results_df
# Out:
# Error or no results for university at location (45.492157, -73.709819): ZERO_RESULTS
# Error or no results for university at location (45.5812866, -73.6405367): ZERO_RESULTS
# Error or no results for university at location (45.5281968, -73.6481237): ZERO_RESULTS
# Error or no results for university at location (45.44045240000001, -73.6222118): ZERO_RESULTS
#                                       Bubble Tea Shop   Latitude  Longitude  \
# 0                                     Bubble Tea Shop  45.536106 -73.613523
# 1                                     Bubble Tea Shop  45.498627 -73.570964
# 2                                     Bubble Tea Shop  45.501355 -73.570814
# 3                                        OLa Boba Tea  45.583184 -73.542436
# 4                                             Chatime  45.508589 -73.572116
# 5                                  The Alley Montreal  45.494823 -73.577654
# 6                                     Bubble Tea Shop  45.495379 -73.579280
# 7                                            Gong Cha  45.525748 -73.581550
# 8                                     Bubble Tea Shop  45.452951 -73.645885
# 9                               Real Fruit Bubble Tea  45.502673 -73.571714
# 10                                              MTL T  45.475646 -73.607027
# 11                              Real Fruit Bubble Tea  45.507712 -73.563628
# 12                                    Bubble Tea Shop  45.593378 -73.668303
# 13                                Presotea Jean Talon  45.538354 -73.614180
# 14                                        Gong Cha 貢茶  45.493685 -73.579696
# 15                                    Bubble Tea Shop  45.500112 -73.566522
# 16                                    Bubble Tea Shop  45.519181 -73.587488
# 17                                          Labothery  45.475021 -73.608280
# 18                                          Boba Boba  45.479655 -73.577099
# 19                 Chatime Montreal Chinatown (~24/7)  45.507583 -73.560212
# 20                                    Presotea McGill  45.505168 -73.571600
# 21                       Chatime VSL (Thé aux perles)  45.524314 -73.713516
# 22                                    Bubble Tea Shop  45.594248 -73.574251
# 23                                    Bubble Tea Shop  45.589869 -73.539313
# 24                                    Bubble Tea Shop  45.498171 -73.626799
# 25                                   One Babo - Laval  45.567628 -73.727436
# 26                              One Babo - Côte-Vertu  45.512505 -73.679575
# 27                                    Bubble Tea Shop  45.440537 -73.692921
# 28                                      Presotea Peel  45.501110 -73.572243
# 29                                    Bubble Tea Shop  45.492157 -73.709819
# 30                                Presotea Mont-Royal  45.523651 -73.583034
# 31                                    Bubble Tea Shop  45.479671 -73.577271
# 32                                        Machi Machi  45.496288 -73.575344
# 33                                     Koi Bubble Tea  45.553615 -73.602323
# 34                           One Babo Plaza St-Hubert  45.537396 -73.606276
# 35                                          L2 Lounge  45.507341 -73.560744
# 36                                       Panda Boba-T  45.587124 -73.561693
# 37                                Presotea Côte-Vertu  45.514181 -73.682351
# 38                             Shuyi Tealicious 书亦烧仙草  45.503368 -73.574862
# 39                         L2 Bubble tea Alexis Nihon  45.489217 -73.586064
# 40                                       The o Bulles  45.581287 -73.640537
# 41                            Maison O Thé Queen Mary  45.483417 -73.629617
# 42                                    Bubble Tea Shop  45.505562 -73.555343
# 43                  Song Thé - Song Tea (Montreal) 丧茶  45.494332 -73.580378
# 44                                           Presotea  45.506889 -73.568438
# 45                                    Bubble Tea Shop  45.435338 -73.627206
# 46                               Tiger Sugar Montréal  45.496189 -73.577418
# 47                                    Bubble Tea Shop  45.507711 -73.563628
# 48                                    Bubble Tea Shop  45.473220 -73.600918
# 49                              Real Fruit Bubble Tea  45.528197 -73.648124
# 50                                               OCHA  45.494411 -73.578855
# 51                                    Bubble Tea Shop  45.501780 -73.560170
# 52                                   Presotea Lasalle  45.440452 -73.622212
# 53              Kung Fu Tea Montreal (Vieux-Montréal)  45.505341 -73.556503
# 54                                           Presotea  45.496211 -73.622378
# 55                             C’est du Thé / ITS TEA  45.496678 -73.574900
# 56                                          IBoBa Thé  45.557938 -73.659422
# 57                   COCO Fresh tea & Juice NDG store  45.498543 -73.626801
# 58                                        Palgong Tea  45.521987 -73.602177
# 59  CoCo Fresh Tea & Juice CoCo thé et jus frais 都...  45.496652 -73.575901
#
#                        Place ID  Number of Nearby Colleges  \
# 0   ChIJrRPobmMZyUwRmzUtZysr570                          7
# 1   ChIJk0Ay_ZwbyUwRtjPsppB80xM                         60
# 2   ChIJh1KLHbAbyUwR5DRuYkp1Gvg                         60
# 3   ChIJe-mGnqcdyUwRDR7LWixnrUY                          4
# 4   ChIJ1xjTVUgayUwRvxmlGV6LkLU                         60
# 5   ChIJ0XpAvrgbyUwRLq2_-QxhoO4                         60
# 6   ChIJuQHWPh0byUwRlgTAaNZ68yE                         60
# 7   ChIJOXWPWI0byUwRI-q2TjxNmGQ                          4
# 8   ChIJb3yKdrAXyUwRxKieAJfUEKU                          6
# 9   ChIJLWhYybIbyUwROq0s6LLmi2w                         60
# 10  ChIJEXZ1HaQRyUwR4KzH_ie88Jk                          2
# 11  ChIJ2YIWUecbyUwR9dwIA5n5kew                         58
# 12  ChIJJ4q1ZiQhyUwRpNWXeVj2eE0                          1
# 13  ChIJAyGeox0ZyUwReuT3KQqy2_w                          5
# 14  ChIJ7cBPbs4byUwRHzgzoXsNDuo                         52
# 15  ChIJd72AyjEbyUwRgeNuoQoN7EQ                         59
# 16  ChIJVXHZSRobyUwRsTF0plWq1SU                          8
# 17  ChIJj9vQtuoRyUwReXAqIa08zNo                          2
# 18  ChIJu1N0vRAbyUwRD3b-kXzZunE                          1
# 19  ChIJnYVHsFEayUwR7qbzuA3Aqfs                         44
# 20  ChIJJ6qLtlgbyUwRIl73irem3_E                         60
# 21  ChIJO9FtV1gjyUwRlXs1esOR36A                          1
# 22  ChIJ5ZtrcJEfyUwR2mxbeUPtmCw                          1
# 23  ChIJY9G2F0UdyUwReshXsCQmzE0                          1
# 24  ChIJy-aPl0UZyUwR18xQZEM5azQ                         38
# 25  ChIJQVF4HyAjyUwRpV1fDj1uq7k                          3
# 26  ChIJiyPsxHQZyUwRyQA6OxH6SGs                          8
# 27  ChIJyeaKWrAXyUwRxOEgydm0VrM                          1
# 28  ChIJrVgwbzwbyUwRJhhHFyPJfsg                         60
# 29  ChIJ2R7lBZkXyUwR7XueyWn1DEk                          0
# 30  ChIJ3fB2StMbyUwRDcUBJ-9_eWk                          5
# 31  ChIJj9j6UZIbyUwRC7oHf-dbP6g                          1
# 32  ChIJLy87fL8byUwR-NUOH_z1laA                         60
# 33  ChIJx_q-40kZyUwR4xZHMkd2Mz4                          3
# 34  ChIJOwEL5m4ZyUwRp_HojwZttjw                          6
# 35  ChIJV-rdslEayUwRRcBCvcRp_-8                         45
# 36  ChIJ45CGLJsfyUwRWiP2fHXJRnk                          1
# 37  ChIJ49-SBx4ZyUwROLESZWQUAeQ                          8
# 38  ChIJzzMHPR4byUwRmYvf8L1MoCY                         60
# 39  ChIJ2-VBW2gbyUwRsRtRh_2R8Ls                         32
# 40  ChIJwUJ_bDMfyUwRa9VROjvQ5LA                          0
# 41  ChIJBaZROr0XyUwRVPV32qWALWw                          7
# 42  ChIJ3cLeRBUbyUwRTz6Eb0ZdOKA                         16
# 43  ChIJB2mLpVEbyUwRtlu_uHcA8Ak                         56
# 44  ChIJaa4ARiUbyUwRP8OpkOBeAMU                         60
# 45  ChIJbxOMo0wRyUwRnZRUrJQC8co                          3
# 46  ChIJoeNGAjwbyUwRcPoZHmiKVrU                         60
# 47  ChIJybSb0IobyUwRdzj16GXLx2E                         58
# 48  ChIJGdlgCcoRyUwRnJdnwvw2hqU                          1
# 49  ChIJjZnSgWcZyUwRadG4smP-FvA                          0
# 50  ChIJr1LHuxkbyUwRujQmeAk5C2g                         57
# 51  ChIJG1Njs2sbyUwRlglb_KzPvyo                         29
# 52  ChIJ-5uMFkgRyUwRQjoJSVO987o                          0
# 53  ChIJWc4eP90byUwREgXjg-EOJiM                         21
# 54  ChIJ85yPT8gZyUwRP4ILdax0-WE                         38
# 55  ChIJU8XBzsQbyUwRm_nsQDttDGE                         60
# 56  ChIJW-IGLtcZyUwRiwC2MFJWyPY                          3
# 57  ChIJ9d0MkEYZyUwRZkj4KRq3sUE                         39
# 58  ChIJD0hcH0EZyUwRCXfbaICpa4U                          5
# 59  ChIJaSZ6A2IbyUwR6uaHoiRWEcU                         60
#
#                                       Nearby Colleges  \
# 0   [University of Montreal School of Public Healt...
# 1   [McGill University, École de technologie supér...
# 2   [McGill University, O'Sullivan College, Desaut...
# 3   [voy k5, College Institute Trudeau Internation...
# 4   [McGill University, Cegep of Old Montreal, Uni...
# 5   [Collège of Montréal, Collège LaSalle, O'Sulli...
# 6   [Collège of Montréal, Collège LaSalle, O'Sulli...
# 7   [GERIQ - Groupe d'études et de recherche sur l...
# 8   [Concordia University - Loyola Campus, Centre ...
# 9   [McGill University, O'Sullivan College, Univer...
# 10  [Marianopolis College, Stone Hon. Paul Gerin -...
# 11  [Cegep of Old Montreal, University of Quebec i...
# 12                                   [college citoyn]
# 13  [CEGEP, École de Clown et Comédie / Clown and ...
# 14  [Collège of Montréal, Collège LaSalle, O'Sulli...
# 15  [École de technologie supérieure ÉTS, O'Sulliv...
# 16  [Projets Alpha Et Omega Inc (Les), GERIQ - Gro...
# 17  [Marianopolis College, Stone Hon. Paul Gerin -...
# 18                                       [University]
# 19  [University of Quebec in Montreal, Cegep of Ol...
# 20  [McGill University, University of Quebec at Mo...
# 21                           [Université De Montréal]
# 22                              [Saurabh vishwakarma]
# 23                                           [voy k5]
# 24  [College Jean-de-Brebeuf, HEC Montreal, Facult...
# 25  [High School Collège Letendre, CEGEP, Studios ...
# 26  [CEGEP, CEGEP, Vanier College, CEGEP, CEGEP, C...
# 27                                               [Gg]
# 28  [McGill University, O'Sullivan College, Desaut...
# 29                                                 []
# 30  [GERIQ - Groupe d'études et de recherche sur l...
# 31                                       [University]
# 32  [Collège of Montréal, Collège LaSalle, O'Sulli...
# 33  [Centre D'Etudes Commercials, Institut techniq...
# 34  [Alliance de la Fonction Publique, CEGEP, Boul...
# 35  [University of Quebec in Montreal, Cegep of Ol...
# 36                              [Saurabh vishwakarma]
# 37  [821 Sainte Croix Ave, Saint – Laurent, Montre...
# 38  [McGill University, O'Sullivan College, Univer...
# 39  [Collège of Montréal, Dawson College, Collège ...
# 40                                                 []
# 41  [Erudit Academy, Marie of France International...
# 42  [University of Quebec in Montreal, ISI, Higher...
# 43  [Collège of Montréal, Collège LaSalle, O'Sulli...
# 44  [McGill University, Cegep of Old Montreal, Uni...
# 45  [Cester College Lasalle Campus, Cestar College...
# 46  [Collège of Montréal, Collège LaSalle, O'Sulli...
# 47  [Cegep of Old Montreal, University of Quebec i...
# 48                   [Stone Hon. Paul Gerin - Lajiue]
# 49                                                 []
# 50  [Collège of Montréal, Collège LaSalle, O'Sulli...
# 51  [École de technologie supérieure ÉTS, ISI, Hig...
# 52                                                 []
# 53  [University of Quebec in Montreal, ISI, Higher...
# 54  [College Jean-de-Brebeuf, HEC Montreal, Facult...
# 55  [Collège of Montréal, McGill University, O'Sul...
# 56  [Cégep De La Gaspésie Et Des Îles - Campus Mon...
# 57  [College Jean-de-Brebeuf, HEC Montreal, Facult...
# 58  [Projets Alpha Et Omega Inc (Les), Studio d'ac...
# 59  [Collège of Montréal, McGill University, Collè...
#
#     Average Distance to Colleges (m)  Shortest Distance to Colleges (m)  \
# 0                         870.000000                              417.0
# 1                         794.750000                              319.0
# 2                         729.716667                                0.0
# 3                         475.000000                              249.0
# 4                         753.333333                              109.0
# 5                         600.233333                               12.0
# 6                         572.333333                               59.0
# 7                         393.000000                                0.0
# 8                         961.166667                              782.0
# 9                         762.600000                              307.0
# 10                        700.000000                              443.0
# 11                        948.810345                              220.0
# 12                        546.000000                              546.0
# 13                        934.600000                              481.0
# 14                        573.153846                              174.0
# 15                        833.423729                              168.0
# 16                        949.375000                              636.0
# 17                        702.500000                              328.0
# 18                       1023.000000                             1023.0
# 19                        930.250000                              234.0
# 20                        621.783333                               48.0
# 21                       1531.000000                             1531.0
# 22                        490.000000                              490.0
# 23                       1034.000000                             1034.0
# 24                        938.210526                              344.0
# 25                        894.000000                              590.0
# 26                        728.875000                              587.0
# 27                        922.000000                              922.0
# 28                        701.950000                              181.0
# 29                               NaN                                NaN
# 30                        474.600000                              196.0
# 31                       1013.000000                             1013.0
# 32                        646.983333                               92.0
# 33                       1071.333333                              951.0
# 34                        950.666667                              415.0
# 35                        934.511111                              171.0
# 36                       1117.000000                             1117.0
# 37                        867.625000                              447.0
# 38                        602.883333                              154.0
# 39                        806.437500                              281.0
# 40                               NaN                                NaN
# 41                        570.000000                              323.0
# 42                       1031.000000                              522.0
# 43                        595.017857                              145.0
# 44                        774.433333                               67.0
# 45                        636.000000                              636.0
# 46                        577.050000                              113.0
# 47                        948.896552                              220.0
# 48                       1200.000000                             1200.0
# 49                               NaN                                NaN
# 50                        568.245614                               70.0
# 51                        843.241379                              179.0
# 52                               NaN                                NaN
# 53                       1018.047619                              394.0
# 54                        703.973684                              142.0
# 55                        688.683333                               48.0
# 56                       1077.666667                              940.0
# 57                        953.794872                              321.0
# 58                        909.000000                              558.0
# 59                        593.916667                               96.0
#
#     Number of Nearby Schools  \
# 0                         60
# 1                         60
# 2                         60
# 3                         24
# 4                         60
# 5                         60
# 6                         60
# 7                         60
# 8                         35
# 9                         60
# 10                        40
# 11                        60
# 12                        17
# 13                        60
# 14                        60
# 15                        60
# 16                        60
# 17                        41
# 18                        40
# 19                        60
# 20                        60
# 21                        16
# 22                        14
# 23                        14
# 24                        58
# 25                        11
# 26                        39
# 27                        12
# 28                        60
# 29                         7
# 30                        60
# 31                        40
# 32                        60
# 33                        38
# 34                        60
# 35                        60
# 36                        16
# 37                        41
# 38                        60
# 39                        60
# 40                        22
# 41                        52
# 42                        54
# 43                        60
# 44                        60
# 45                        15
# 46                        60
# 47                        60
# 48                        44
# 49                        13
# 50                        60
# 51                        60
# 52                        11
# 53                        60
# 54                        49
# 55                        60
# 56                        31
# 57                        59
# 58                        49
# 59                        60
#
#                                        Nearby Schools  \
# 0   [École La Petite-Patrie, Pavillon Saint-Jean-D...
# 1   [EC Montreal English Language School, MLS, F.A...
# 2   [University of Quebec at Montreal, F.A.C.E. El...
# 3   [Scout, Espace Voix | Singing Lessons And Musi...
# 4   [University of Quebec at Montreal, Montreal Hi...
# 5   [Collège of Montréal, EC Montreal English Lang...
# 6   [Collège of Montréal, Académie Michèle-Provost...
# 7   [Laurier Elementary School, Yoga Sangha, Nurse...
# 8   [Loyola High School, Collège Prep Internationa...
# 9   [University of Quebec at Montreal, F.A.C.E. El...
# 10  [Centre des arts visuels / The Visual Arts Cen...
# 11  [University of Quebec at Montreal, F.A.C.E. El...
# 12  [L'Envol, School Of Music Shading Musical Mary...
# 13  [École La Petite-Patrie, Pavillon Saint-Jean-D...
# 14  [Collège of Montréal, Académie Michèle-Provost...
# 15  [Imagination Preschool & Nursery, MLS, F.A.C.E...
# 16  [Yoga Sangha, Francais College, Bancroft Eleme...
# 17  [Centre des arts visuels / The Visual Arts Cen...
# 18  [Profaqua Inc., Ali school, Safa Driving Schoo...
# 19  [University of Quebec at Montreal, EFPHQ Vocat...
# 20  [University of Quebec at Montreal, F.A.C.E. El...
# 21  [Louisbourg Elementary School, Académie An-Noo...
# 22  [Dante Elementary School, Cour de Frigoriste A...
# 23  [Scout, Académie Dunton, École de langues Lang...
# 24  [College Jean-de-Brebeuf, HEC Montreal, Notre-...
# 25  [High School Collège Letendre, École Démosthèn...
# 26  [Mr Doremi, 3D VR Driving School, École de con...
# 27  [Collège Saint-Louis, Berges-de-Lachine Elemen...
# 28  [University of Quebec at Montreal, F.A.C.E. El...
# 29  [Commission Scolaire Kativik, TOTI Virtual Tea...
# 30  [Laurier Elementary School, Yoga Sangha, Bancr...
# 31  [Profaqua Inc., Ali school, Safa Driving Schoo...
# 32  [Collège of Montréal, EC Montreal English Lang...
# 33  [Pierre Elliott Trudeau Elementary School, Sai...
# 34  [École La Petite-Patrie, Pavillon Saint-Jean-D...
# 35  [University of Quebec at Montreal, EFPHQ Vocat...
# 36  [École primaire Guillaume-Couture, Centre Tétr...
# 37  [3D VR Driving School, École de conduite • PRE...
# 38  [University of Quebec at Montreal, F.A.C.E. El...
# 39  [Collège of Montréal, Westmount High School, L...
# 40  [École primaire Saint-Rémi, Atelier Elementary...
# 41  [Academy Security I.G.S., Villa Maria College,...
# 42  [Imagination Preschool & Nursery, EFPHQ Vocati...
# 43  [Collège of Montréal, Académie Michèle-Provost...
# 44  [University of Quebec at Montreal, F.A.C.E. El...
# 45  [École Montessori de Montréal, Julia Tutoring,...
# 46  [Collège of Montréal, Académie Michèle-Provost...
# 47  [University of Quebec at Montreal, F.A.C.E. El...
# 48  [Centre des arts visuels / The Visual Arts Cen...
# 49  [OnlinePastryTrainingSchool.com, Centre Musica...
# 50  [Collège of Montréal, Académie Michèle-Provost...
# 51  [Imagination Preschool & Nursery, EFPHQ Vocati...
# 52  [École Montessori de Montréal, Wonderland Pres...
# 53  [Imagination Preschool & Nursery, EFPHQ Vocati...
# 54  [College Jean-de-Brebeuf, HEC Montreal, Notre-...
# 55  [Collège of Montréal, EC Montreal English Lang...
# 56  [École Fernand-Seguin, Pavillon Hubert-Reeves,...
# 57  [College Jean-de-Brebeuf, HEC Montreal, Notre-...
# 58  [Francais College, École De Sténographie Judic...
# 59  [Collège of Montréal, EC Montreal English Lang...
#
#     Average Distance to Schools (m)  Shortest Distance to Schools (m)
# 0                        723.466667                               120
# 1                        666.650000                                 6
# 2                        601.350000                                 4
# 3                        791.291667                                59
# 4                        633.583333                               162
# 5                        479.783333                                 3
# 6                        467.066667                                59
# 7                        702.183333                                37
# 8                        871.028571                                94
# 9                        647.400000                               199
# 10                       719.700000                                39
# 11                       801.800000                               220
# 12                       723.176471                               114
# 13                       709.166667                               125
# 14                       490.766667                                67
# 15                       637.933333                               210
# 16                       697.600000                               113
# 17                       698.756098                               131
# 18                       873.300000                               127
# 19                       770.816667                               234
# 20                       464.333333                                46
# 21                      1023.062500                               470
# 22                      1052.642857                               410
# 23                       870.357143                               119
# 24                       880.465517                               145
# 25                       883.909091                               273
# 26                       783.871795                               247
# 27                       985.500000                               653
# 28                       575.783333                               185
# 29                       907.714286                               558
# 30                       664.283333                               194
# 31                       871.800000                               117
# 32                       607.233333                                57
# 33                       759.394737                               189
# 34                       755.750000                               105
# 35                       755.183333                               171
# 36                       887.750000                               303
# 37                       807.707317                                43
# 38                       541.200000                               161
# 39                       819.833333                               231
# 40                       634.681818                                 8
# 41                       763.000000                               101
# 42                       774.370370                                 7
# 43                       522.383333                                52
# 44                       590.366667                               161
# 45                       859.333333                               448
# 46                       514.383333                                78
# 47                       801.766667                               220
# 48                      1166.840909                               589
# 49                      1270.692308                               849
# 50                       465.166667                                 3
# 51                       634.650000                               177
# 52                      1101.181818                               205
# 53                       756.150000                                65
# 54                       785.571429                               127
# 55                       673.450000                               143
# 56                       795.806452                               164
# 57                       889.203390                               167
# 58                       791.836735                                78
# 59                       594.033333                                53

# %%
# Save the results back to a new CSV
results_df.to_csv('schools.csv', index=False)

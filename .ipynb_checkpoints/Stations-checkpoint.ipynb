# %%
import requests
import pandas as pd

# URL of the API endpoint
url = 'https://api.citybik.es/v2/networks/bixi-montreal'

# GET request to the API
response = requests.get(url)
# Out:
# /Users/selwynreuangrith/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Check if the request was successful (status code 200)

if response.status_code != 200:
    print("Request failed. Status code:", response.status_code)
else:
    data = response.json()
    
    # Extract station details
    stations = data['network']['stations']

    # Create lists to store extracted details
    name = []
    latitudes = []
    longitudes = []

    # Iterate through each station and extract details
    for station in stations:
        name.append(station['name'])
        latitudes.append(station['latitude'])
        longitudes.append(station['longitude'])

# %%
# Create a DataFrame with the extracted details
df = pd.DataFrame({
    'Station Name': name,
    'Latitude': latitudes,
    'Longitude': longitudes
})

# %%
print(df)
# Out:
#                                           Station Name   Latitude  Longitude
# 0        Gare d'autocars de Montréal (Berri / Ontario)  45.516926 -73.564257
# 1                                   Marché Maisonneuve  45.553219 -73.539782
# 2                                  Rachel / de Brébeuf  45.526890 -73.572640
# 3        Bibliothèque d'Ahuntsic (Lajeunesse / Fleury)  45.553400 -73.662255
# 4    Cité des Arts du Cirque (Paul Boutet / des Reg...  45.559842 -73.615447
# ..                                                 ...        ...        ...
# 156                         du Mont-Royal / de Brébeuf  45.529337 -73.577953
# 157                                    K5 Test Station  45.530298 -73.601398
# 158                              Ste-Catherine / Union  45.503704 -73.569415
# 159  Place du Canada (Peel / des Canadiens-de-Montr...  45.497796 -73.568251
# 160                                   Aylwin / Ontario  45.544290 -73.545232
#
# [161 rows x 3 columns]

# %%
df.to_csv('bike_stations.csv',index=False)

# %%
import os
import time
import json
import csv

PLACES_API_KEY = os.environ['PLACES_API_KEY']

# %%
def find_bus_stations(api_key, latitude, longitude, radius=1000):
    endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    location = f"{latitude},{longitude}"

    params = {
        'location': location,
        'radius': radius,
        'types': 'bus_station',
        'key': api_key,
    }

    bus_station_count = 0
    next_page_token = None

    while True:
        if next_page_token:
            params['pagetoken'] = next_page_token

        response = requests.get(endpoint, params=params)
        results = response.json()

        if response.status_code == 200 and results['status'] == 'OK':
            bus_station_count += len(results['results'])

            # Check if there are more pages
            next_page_token = results.get('next_page_token')

            # Wait for a short time before making the next request
            time.sleep(2)

            # Break the loop if there are no more pages
            if not next_page_token:
                break
        else:
            print(f"Error: {results['status']}")
            return None

    return bus_station_count

def process_csv2(api_key, input_csv2, output_csv2):
    with open(input_csv2, 'r') as infile, open(output_csv2, 'w', newline='') as outfile:
        reader = csv.DictReader(infile)
        fieldnames = reader.fieldnames + ['Bus_Stations_Count']

        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        writer.writeheader()

        for row in reader:
            latitude = float(row['Latitude'])  
            longitude = float(row['Longitude'])

            bus_station_count = find_bus_stations(api_key, latitude, longitude)

            if bus_station_count is not None:
                row['Bus_Stations_Count'] = bus_station_count
                print(f"For location ({latitude}, {longitude}), number of bus stations within 1km radius: {bus_station_count}")
            else:
                print(f"Unable to fetch data for location ({latitude}, {longitude})")

            writer.writerow(row)

api_key = PLACES_API_KEY
input_csv_path = 'boba_shops.csv'  
output_csv_path = 'bus_stations.csv'  

process_csv2(api_key, input_csv_path, output_csv_path)
# Out:
# For location (45.5361062, -73.6135235), number of bus stations within 1km radius: 18
# For location (45.498627, -73.5709641), number of bus stations within 1km radius: 31
# For location (45.501355, -73.570814), number of bus stations within 1km radius: 33
# For location (45.58318389999999, -73.54243559999999), number of bus stations within 1km radius: 18
# For location (45.5085893, -73.5721164), number of bus stations within 1km radius: 22
# For location (45.4948234, -73.57765429999999), number of bus stations within 1km radius: 30
# For location (45.495379, -73.57928), number of bus stations within 1km radius: 28
# For location (45.5257478, -73.58154979999999), number of bus stations within 1km radius: 12
# For location (45.4529508, -73.6458851), number of bus stations within 1km radius: 1
# For location (45.5026725, -73.57171389999999), number of bus stations within 1km radius: 33
# For location (45.4756456, -73.60702669999999), number of bus stations within 1km radius: 8
# For location (45.5077116, -73.56362829999999), number of bus stations within 1km radius: 30
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.593378, -73.668303)
# For location (45.5383545, -73.6141796), number of bus stations within 1km radius: 16
# For location (45.493685, -73.57969609999999), number of bus stations within 1km radius: 26
# For location (45.500112, -73.56652199999999), number of bus stations within 1km radius: 33
# For location (45.519181, -73.587488), number of bus stations within 1km radius: 12
# For location (45.4750208, -73.6082796), number of bus stations within 1km radius: 8
# For location (45.4796547, -73.5770991), number of bus stations within 1km radius: 17
# For location (45.5075827, -73.56021249999999), number of bus stations within 1km radius: 27
# For location (45.5051682, -73.57160010000001), number of bus stations within 1km radius: 33
# For location (45.524314, -73.7135165), number of bus stations within 1km radius: 1
# For location (45.594248, -73.57425099999999), number of bus stations within 1km radius: 2
# For location (45.589869, -73.53931299999999), number of bus stations within 1km radius: 28
# For location (45.4981713, -73.6267989), number of bus stations within 1km radius: 13
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.5676282, -73.72743559999999)
# For location (45.51250539999999, -73.6795752), number of bus stations within 1km radius: 28
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.4405365, -73.6929213)
# For location (45.50111, -73.57224269999999), number of bus stations within 1km radius: 35
# For location (45.492157, -73.709819), number of bus stations within 1km radius: 1
# For location (45.5236511, -73.5830342), number of bus stations within 1km radius: 12
# For location (45.4796712, -73.5772715), number of bus stations within 1km radius: 17
# For location (45.4962882, -73.5753441), number of bus stations within 1km radius: 31
# For location (45.55361540000001, -73.6023232), number of bus stations within 1km radius: 14
# For location (45.537396, -73.606276), number of bus stations within 1km radius: 21
# For location (45.5073406, -73.5607436), number of bus stations within 1km radius: 27
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.58712449999999, -73.5616932)
# For location (45.5141807, -73.68235109999999), number of bus stations within 1km radius: 25
# For location (45.5033684, -73.57486229999999), number of bus stations within 1km radius: 30
# For location (45.4892168, -73.58606449999999), number of bus stations within 1km radius: 26
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.5812866, -73.6405367)
# For location (45.4834167, -73.6296174), number of bus stations within 1km radius: 9
# For location (45.505562, -73.555343), number of bus stations within 1km radius: 9
# For location (45.4943323, -73.5803777), number of bus stations within 1km radius: 26
# For location (45.5068891, -73.56843830000001), number of bus stations within 1km radius: 30
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.4353377, -73.6272065)
# For location (45.4961893, -73.5774184), number of bus stations within 1km radius: 30
# For location (45.507711, -73.563628), number of bus stations within 1km radius: 30
# For location (45.47322, -73.600918), number of bus stations within 1km radius: 8
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.5281968, -73.6481237)
# For location (45.4944114, -73.5788549), number of bus stations within 1km radius: 27
# For location (45.5017799, -73.56017), number of bus stations within 1km radius: 23
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.44045240000001, -73.6222118)
# For location (45.5053411, -73.5565033), number of bus stations within 1km radius: 11
# For location (45.4962109, -73.62237809999999), number of bus stations within 1km radius: 10
# For location (45.49667849999999, -73.5749001), number of bus stations within 1km radius: 29
# For location (45.557938, -73.65942179999999), number of bus stations within 1km radius: 19
# For location (45.4985432, -73.6268012), number of bus stations within 1km radius: 13
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.521987, -73.6021773)
# For location (45.496652, -73.5759009), number of bus stations within 1km radius: 31

# %%
def find_metro_stations(api_key, latitude, longitude, radius=1000):
    endpoint = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    location = f"{latitude},{longitude}"

    params = {
        'location': location,
        'radius': radius,
        'types': 'subway_station',
        'key': api_key,
    }

    metro_station_count = 0
    next_page_token = None

    while True:
        if next_page_token:
            params['pagetoken'] = next_page_token

        response = requests.get(endpoint, params=params)
        results = response.json()

        if response.status_code == 200 and results['status'] == 'OK':
            metro_station_count += len(results['results'])

            # Check if there are more pages
            next_page_token = results.get('next_page_token')

            # Wait for a short time before making the next request
            time.sleep(2)

            # Break the loop if there are no more pages
            if not next_page_token:
                break
        else:
            print(f"Error: {results['status']}")
            return None

    return metro_station_count

def process_csv(api_key, input_csv, output_csv):
    with open(input_csv, 'r') as infile, open(output_csv, 'w', newline='') as outfile:
        reader = csv.DictReader(infile)
        fieldnames = reader.fieldnames + ['Metro_Stations_Count']

        writer = csv.DictWriter(outfile, fieldnames=fieldnames)
        writer.writeheader()

        for row in reader:
            latitude = float(row['Latitude'])  
            longitude = float(row['Longitude'])

            metro_station_count = find_metro_stations(api_key, latitude, longitude)

            if metro_station_count is not None:
                row['Metro_Stations_Count'] = metro_station_count
                print(f"For location ({latitude}, {longitude}), number of metro stations within 1km radius: {metro_station_count}")
            else:
                print(f"Unable to fetch data for location ({latitude}, {longitude})")

            writer.writerow(row)

api_key = PLACES_API_KEY
input_csv_path = 'boba_shops.csv'  
output_csv_path = 'metro_stations.csv' 

process_csv(api_key, input_csv_path, output_csv_path)
# Out:
# For location (45.5361062, -73.6135235), number of metro stations within 1km radius: 3
# For location (45.498627, -73.5709641), number of metro stations within 1km radius: 6
# For location (45.501355, -73.570814), number of metro stations within 1km radius: 8
# For location (45.58318389999999, -73.54243559999999), number of metro stations within 1km radius: 3
# For location (45.5085893, -73.5721164), number of metro stations within 1km radius: 4
# For location (45.4948234, -73.57765429999999), number of metro stations within 1km radius: 6
# For location (45.495379, -73.57928), number of metro stations within 1km radius: 5
# For location (45.5257478, -73.58154979999999), number of metro stations within 1km radius: 2
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.4529508, -73.6458851)
# For location (45.5026725, -73.57171389999999), number of metro stations within 1km radius: 8
# For location (45.4756456, -73.60702669999999), number of metro stations within 1km radius: 1
# For location (45.5077116, -73.56362829999999), number of metro stations within 1km radius: 7
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.593378, -73.668303)
# For location (45.5383545, -73.6141796), number of metro stations within 1km radius: 3
# For location (45.493685, -73.57969609999999), number of metro stations within 1km radius: 5
# For location (45.500112, -73.56652199999999), number of metro stations within 1km radius: 7
# For location (45.519181, -73.587488), number of metro stations within 1km radius: 2
# For location (45.4750208, -73.6082796), number of metro stations within 1km radius: 1
# For location (45.4796547, -73.5770991), number of metro stations within 1km radius: 3
# For location (45.5075827, -73.56021249999999), number of metro stations within 1km radius: 7
# For location (45.5051682, -73.57160010000001), number of metro stations within 1km radius: 7
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.524314, -73.7135165)
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.594248, -73.57425099999999)
# For location (45.589869, -73.53931299999999), number of metro stations within 1km radius: 3
# For location (45.4981713, -73.6267989), number of metro stations within 1km radius: 4
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.5676282, -73.72743559999999)
# For location (45.51250539999999, -73.6795752), number of metro stations within 1km radius: 2
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.4405365, -73.6929213)
# For location (45.50111, -73.57224269999999), number of metro stations within 1km radius: 7
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.492157, -73.709819)
# For location (45.5236511, -73.5830342), number of metro stations within 1km radius: 2
# For location (45.4796712, -73.5772715), number of metro stations within 1km radius: 3
# For location (45.4962882, -73.5753441), number of metro stations within 1km radius: 6
# For location (45.55361540000001, -73.6023232), number of metro stations within 1km radius: 3
# For location (45.537396, -73.606276), number of metro stations within 1km radius: 3
# For location (45.5073406, -73.5607436), number of metro stations within 1km radius: 7
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.58712449999999, -73.5616932)
# For location (45.5141807, -73.68235109999999), number of metro stations within 1km radius: 2
# For location (45.5033684, -73.57486229999999), number of metro stations within 1km radius: 7
# For location (45.4892168, -73.58606449999999), number of metro stations within 1km radius: 4
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.5812866, -73.6405367)
# For location (45.4834167, -73.6296174), number of metro stations within 1km radius: 2
# For location (45.505562, -73.555343), number of metro stations within 1km radius: 4
# For location (45.4943323, -73.5803777), number of metro stations within 1km radius: 5
# For location (45.5068891, -73.56843830000001), number of metro stations within 1km radius: 8
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.4353377, -73.6272065)
# For location (45.4961893, -73.5774184), number of metro stations within 1km radius: 7
# For location (45.507711, -73.563628), number of metro stations within 1km radius: 7
# For location (45.47322, -73.600918), number of metro stations within 1km radius: 1
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.5281968, -73.6481237)
# For location (45.4944114, -73.5788549), number of metro stations within 1km radius: 5
# For location (45.5017799, -73.56017), number of metro stations within 1km radius: 6
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.44045240000001, -73.6222118)
# For location (45.5053411, -73.5565033), number of metro stations within 1km radius: 5
# For location (45.4962109, -73.62237809999999), number of metro stations within 1km radius: 3
# For location (45.49667849999999, -73.5749001), number of metro stations within 1km radius: 6
# For location (45.557938, -73.65942179999999), number of metro stations within 1km radius: 2
# For location (45.4985432, -73.6268012), number of metro stations within 1km radius: 4
# Error: ZERO_RESULTS
# Unable to fetch data for location (45.521987, -73.6021773)
# For location (45.496652, -73.5759009), number of metro stations within 1km radius: 6

# %%
def get_distance_matrix_biking(origin, destination):
    endpoint = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        'origins': f'{origin[0]},{origin[1]}',
        'destinations': f'{destination[0]},{destination[1]}',
        'mode': 'bicycling',
        'key': api_key
    }
    response = requests.get(endpoint, params=params)
    result = response.json()

    return result['rows'][0]['elements'][0]['distance']['text'], result['rows'][0]['elements'][0]['duration']['text']

# Read CSV files
origins_df = pd.read_csv('boba_shops.csv')
destinations_df = pd.read_csv('bike_stations.csv')

# Iterate through each pair and get biking distance matrix
for i, origin_row in origins_df.iterrows():
    for j, dest_row in destinations_df.iterrows():
        origin = (origin_row['Latitude'], origin_row['Longitude'])
        destination = (dest_row['Latitude'], dest_row['Longitude'])
        distance, duration = get_distance_matrix_biking(origin, destination)
        print(f'Distance from {origin} to {destination} by bike: {distance}, Duration: {duration}')
# Out:
# Distance from (45.5361062, -73.6135235) to (45.516926210319546, -73.56425732374191) by bike: 5.1 km, Duration: 17 mins
# Distance from (45.5361062, -73.6135235) to (45.55321884238814, -73.53978216648102) by bike: 8.2 km, Duration: 30 mins
# Distance from (45.5361062, -73.6135235) to (45.52689, -73.57264) by bike: 4.0 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.5534000891078, -73.66225451231003) by bike: 4.6 km, Duration: 17 mins
# Distance from (45.5361062, -73.6135235) to (45.55984236120471, -73.61544728279114) by bike: 3.8 km, Duration: 17 mins
# Distance from (45.5361062, -73.6135235) to (45.5457759528664, -73.56217458844185) by bike: 5.5 km, Duration: 18 mins
# Distance from (45.5361062, -73.6135235) to (45.55988367688166, -73.63356828689575) by bike: 4.1 km, Duration: 15 mins
# Distance from (45.5361062, -73.6135235) to (45.5616903, -73.610512) by bike: 4.1 km, Duration: 17 mins
# Distance from (45.5361062, -73.6135235) to (45.53830765459552, -73.6548838019371) by bike: 4.3 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.55675103297278, -73.66716161370277) by bike: 5.3 km, Duration: 19 mins
# Distance from (45.5361062, -73.6135235) to (45.52783154456306, -73.5719096660614) by bike: 4.1 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.53519006163501, -73.61548215150833) by bike: 0.3 km, Duration: 1 min
# Distance from (45.5361062, -73.6135235) to (45.53330725719417, -73.62082242965698) by bike: 1.0 km, Duration: 5 mins
# Distance from (45.5361062, -73.6135235) to (45.51689731423111, -73.58910799026489) by bike: 3.8 km, Duration: 13 mins
# Distance from (45.5361062, -73.6135235) to (45.51586835126322, -73.56008380651474) by bike: 5.3 km, Duration: 18 mins
# Distance from (45.5361062, -73.6135235) to (45.55969734528566, -73.60145956277847) by bike: 4.2 km, Duration: 16 mins
# Distance from (45.5361062, -73.6135235) to (45.55463653358596, -73.61255215771962) by bike: 2.9 km, Duration: 12 mins
# Distance from (45.5361062, -73.6135235) to (45.55774990838239, -73.58380123972893) by bike: 3.9 km, Duration: 16 mins
# Distance from (45.5361062, -73.6135235) to (45.54365380040509, -73.55942063033581) by bike: 6.0 km, Duration: 21 mins
# Distance from (45.5361062, -73.6135235) to (45.54710313981358, -73.54892447590828) by bike: 6.9 km, Duration: 26 mins
# Distance from (45.5361062, -73.6135235) to (45.51601387670667, -73.56291957199574) by bike: 5.0 km, Duration: 16 mins
# Distance from (45.5361062, -73.6135235) to (45.529668174024685, -73.60166944563389) by bike: 1.7 km, Duration: 6 mins
# Distance from (45.5361062, -73.6135235) to (45.55970526805903, -73.55155438184738) by bike: 8.0 km, Duration: 29 mins
# Distance from (45.5361062, -73.6135235) to (45.53946063965585, -73.57605636119843) by bike: 4.4 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.5121682576952, -73.55481594800949) by bike: 5.8 km, Duration: 20 mins
# Distance from (45.5361062, -73.6135235) to (45.526991277453526, -73.55821162462234) by bike: 5.8 km, Duration: 21 mins
# Distance from (45.5361062, -73.6135235) to (45.52097057660443, -73.5499919950962) by bike: 6.5 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.50206, -73.56295) by bike: 6.6 km, Duration: 24 mins
# Distance from (45.5361062, -73.6135235) to (45.50038, -73.57507) by bike: 6.6 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.50631445605528, -73.55967122894072) by bike: 6.1 km, Duration: 23 mins
# Distance from (45.5361062, -73.6135235) to (45.50928678961862, -73.57101917266846) by bike: 5.4 km, Duration: 19 mins
# Distance from (45.5361062, -73.6135235) to (45.52723106564012, -73.58672618865965) by bike: 2.6 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.53370598779895, -73.55217933654784) by bike: 6.4 km, Duration: 24 mins
# Distance from (45.5361062, -73.6135235) to (45.51941, -73.58685) by bike: 3.5 km, Duration: 13 mins
# Distance from (45.5361062, -73.6135235) to (45.53613488953656, -73.62258464097977) by bike: 1.1 km, Duration: 6 mins
# Distance from (45.5361062, -73.6135235) to (45.53035130173597, -73.6243924498558) by bike: 1.4 km, Duration: 6 mins
# Distance from (45.5361062, -73.6135235) to (45.51862424058306, -73.55219006538391) by bike: 6.2 km, Duration: 21 mins
# Distance from (45.5361062, -73.6135235) to (45.55873962047568, -73.60589044634253) by bike: 3.6 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.49047561880464, -73.56022328138351) by bike: 9.1 km, Duration: 31 mins
# Distance from (45.5361062, -73.6135235) to (45.485328993998365, -73.57692271471024) by bike: 10.9 km, Duration: 37 mins
# Distance from (45.5361062, -73.6135235) to (45.48295816149219, -73.57975836854166) by bike: 11.3 km, Duration: 39 mins
# Distance from (45.5361062, -73.6135235) to (45.55437339981968, -73.55137467384337) by bike: 7.2 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.52551168509886, -73.57424452900887) by bike: 3.8 km, Duration: 13 mins
# Distance from (45.5361062, -73.6135235) to (45.55671730558936, -73.53024959564209) by bike: 9.4 km, Duration: 34 mins
# Distance from (45.5361062, -73.6135235) to (45.51989655507833, -73.58010649681091) by bike: 3.6 km, Duration: 12 mins
# Distance from (45.5361062, -73.6135235) to (45.48378886396517, -73.5750612616539) by bike: 10.7 km, Duration: 37 mins
# Distance from (45.5361062, -73.6135235) to (45.52357479400008, -73.62344294786453) by bike: 2.5 km, Duration: 11 mins
# Distance from (45.5361062, -73.6135235) to (45.54640752148169, -73.63842844963074) by bike: 2.6 km, Duration: 11 mins
# Distance from (45.5361062, -73.6135235) to (45.54218173507584, -73.62268656492233) by bike: 1.3 km, Duration: 7 mins
# Distance from (45.5361062, -73.6135235) to (45.52275023118295, -73.57724860310555) by bike: 3.4 km, Duration: 12 mins
# Distance from (45.5361062, -73.6135235) to (45.55069206841976, -73.65636706352234) by bike: 4.2 km, Duration: 16 mins
# Distance from (45.5361062, -73.6135235) to (45.540105018786974, -73.65347027778625) by bike: 4.5 km, Duration: 16 mins
# Distance from (45.5361062, -73.6135235) to (45.54407915308118, -73.66735741496086) by bike: 5.7 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.51814312154928, -73.56800436973572) by bike: 4.3 km, Duration: 15 mins
# Distance from (45.5361062, -73.6135235) to (45.48020822800015, -73.57759863138199) by bike: 11.2 km, Duration: 39 mins
# Distance from (45.5361062, -73.6135235) to (45.51074821798916, -73.56512099504471) by bike: 5.7 km, Duration: 19 mins
# Distance from (45.5361062, -73.6135235) to (45.55903106539297, -73.54830354452133) by bike: 8.0 km, Duration: 29 mins
# Distance from (45.5361062, -73.6135235) to (45.51329411414168, -73.55057805776596) by bike: 6.2 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.52714838624861, -73.58947947621346) by bike: 2.4 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.53006276144042, -73.54559183120728) by bike: 7.3 km, Duration: 26 mins
# Distance from (45.5361062, -73.6135235) to (45.545350334193245, -73.61032962799072) by bike: 1.6 km, Duration: 7 mins
# Distance from (45.5361062, -73.6135235) to (45.50229349416256, -73.5733064264059) by bike: 6.4 km, Duration: 23 mins
# Distance from (45.5361062, -73.6135235) to (45.527371996141, -73.60398352146149) by bike: 2.5 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.55398156058887, -73.55496388156098) by bike: 6.6 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.5021829099012, -73.56825381517409) by bike: 6.8 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.55315915057821, -73.53263273835182) by bike: 8.9 km, Duration: 32 mins
# Distance from (45.5361062, -73.6135235) to (45.5238445756922, -73.55236601831166) by bike: 6.4 km, Duration: 21 mins
# Distance from (45.5361062, -73.6135235) to (45.49572236030835, -73.55461344122887) by bike: 8.0 km, Duration: 28 mins
# Distance from (45.5361062, -73.6135235) to (45.54902230455398, -73.59198164194822) by bike: 2.7 km, Duration: 12 mins
# Distance from (45.5361062, -73.6135235) to (45.539306918976, -73.59521873295307) by bike: 2.0 km, Duration: 8 mins
# Distance from (45.5361062, -73.6135235) to (45.48830194643546, -73.56871783733366) by bike: 10.0 km, Duration: 34 mins
# Distance from (45.5361062, -73.6135235) to (45.533313304815366, -73.56671154499054) by bike: 4.9 km, Duration: 17 mins
# Distance from (45.5361062, -73.6135235) to (45.52794135176983, -73.62388551235199) by bike: 1.9 km, Duration: 8 mins
# Distance from (45.5361062, -73.6135235) to (45.46976497412213, -73.58923405408859) by bike: 12.7 km, Duration: 43 mins
# Distance from (45.5361062, -73.6135235) to (45.54714142711512, -73.54339510202408) by bike: 7.4 km, Duration: 28 mins
# Distance from (45.5361062, -73.6135235) to (45.51433912935237, -73.56168508529663) by bike: 5.3 km, Duration: 18 mins
# Distance from (45.5361062, -73.6135235) to (45.55897660298603, -73.59951764345168) by bike: 3.1 km, Duration: 13 mins
# Distance from (45.5361062, -73.6135235) to (45.53280412806031, -73.57190161943436) by bike: 4.4 km, Duration: 15 mins
# Distance from (45.5361062, -73.6135235) to (45.53255611409675, -73.58993947505951) by bike: 2.5 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.55458281524975, -73.59631910920143) by bike: 2.5 km, Duration: 10 mins
# Distance from (45.5361062, -73.6135235) to (45.52164617544124, -73.59366774559021) by bike: 3.0 km, Duration: 10 mins
# Distance from (45.5361062, -73.6135235) to (45.54434593245247, -73.57697686180472) by bike: 3.9 km, Duration: 13 mins
# Distance from (45.5361062, -73.6135235) to (45.541602844435374, -73.56496073305605) by bike: 4.9 km, Duration: 16 mins
# Distance from (45.5361062, -73.6135235) to (45.521564270906616, -73.57036739587784) by bike: 4.1 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.4912258547597, -73.58763009309769) by bike: 8.2 km, Duration: 33 mins
# Distance from (45.5361062, -73.6135235) to (45.49658063218649, -73.5762146115303) by bike: 7.3 km, Duration: 28 mins
# Distance from (45.5361062, -73.6135235) to (45.49487159597493, -73.57112377882004) by bike: 7.6 km, Duration: 30 mins
# Distance from (45.5361062, -73.6135235) to (45.49228068089086, -73.58096480369566) by bike: 7.9 km, Duration: 32 mins
# Distance from (45.5361062, -73.6135235) to (45.50531166520915, -73.56089115142822) by bike: 6.2 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.56221872617909, -73.54626774787903) by bike: 8.0 km, Duration: 29 mins
# Distance from (45.5361062, -73.6135235) to (45.49790394592446, -73.57077571808077) by bike: 7.1 km, Duration: 28 mins
# Distance from (45.5361062, -73.6135235) to (45.505173440423306, -73.5706517100334) by bike: 6.0 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.50538591756765, -73.5704317688942) by bike: 5.9 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.51401222645779, -73.56598667800426) by bike: 4.9 km, Duration: 18 mins
# Distance from (45.5361062, -73.6135235) to (45.54699194653282, -73.55115339159964) by bike: 7.0 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.4912954250061, -73.56159925460815) by bike: 9.7 km, Duration: 33 mins
# Distance from (45.5361062, -73.6135235) to (45.51487490356938, -73.58486406505108) by bike: 4.3 km, Duration: 15 mins
# Distance from (45.5361062, -73.6135235) to (45.51059890498207, -73.56692545115948) by bike: 5.2 km, Duration: 20 mins
# Distance from (45.5361062, -73.6135235) to (45.472636238971525, -73.58546018600464) by bike: 12.2 km, Duration: 41 mins
# Distance from (45.5361062, -73.6135235) to (45.4801160762769, -73.58560770750046) by bike: 12.0 km, Duration: 42 mins
# Distance from (45.5361062, -73.6135235) to (45.50238607958335, -73.57333794236183) by bike: 6.3 km, Duration: 23 mins
# Distance from (45.5361062, -73.6135235) to (45.502053864057466, -73.57346534729004) by bike: 6.4 km, Duration: 24 mins
# Distance from (45.5361062, -73.6135235) to (45.512903912221326, -73.57059180741999) by bike: 5.0 km, Duration: 17 mins
# Distance from (45.5361062, -73.6135235) to (45.50277615861811, -73.57589408755302) by bike: 6.3 km, Duration: 23 mins
# Distance from (45.5361062, -73.6135235) to (45.50710632433956, -73.56861054897308) by bike: 5.7 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.498488900657, -73.57436656951904) by bike: 7.1 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.49291337906463, -73.5646878182888) by bike: 8.2 km, Duration: 30 mins
# Distance from (45.5361062, -73.6135235) to (45.5063713381299, -73.5642009973526) by bike: 6.0 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.501187681489775, -73.57045487814501) by bike: 6.6 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.46766565386597, -73.59391784324544) by bike: 13.2 km, Duration: 44 mins
# Distance from (45.5361062, -73.6135235) to (45.53102667048665, -73.59862312674522) by bike: 1.4 km, Duration: 5 mins
# Distance from (45.5361062, -73.6135235) to (45.551961779348346, -73.6303174495697) by bike: 2.8 km, Duration: 12 mins
# Distance from (45.5361062, -73.6135235) to (45.53857953787113, -73.58848571777344) by bike: 2.8 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.53579541676834, -73.55795860291892) by bike: 5.9 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.52571087285848, -73.58128398656845) by bike: 3.1 km, Duration: 11 mins
# Distance from (45.5361062, -73.6135235) to (45.54144823434163, -73.59839379787445) by bike: 1.8 km, Duration: 7 mins
# Distance from (45.5361062, -73.6135235) to (45.52797141659334, -73.54948371648788) by bike: 6.8 km, Duration: 23 mins
# Distance from (45.5361062, -73.6135235) to (45.56157008176612, -73.65338176488876) by bike: 5.3 km, Duration: 19 mins
# Distance from (45.5361062, -73.6135235) to (45.54612833838664, -73.64650368695946) by bike: 3.5 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.56001959585449, -73.534934520776) by bike: 9.1 km, Duration: 34 mins
# Distance from (45.5361062, -73.6135235) to (45.49996470926352, -73.55615437030792) by bike: 7.5 km, Duration: 26 mins
# Distance from (45.5361062, -73.6135235) to (45.529996997063385, -73.63287091255188) by bike: 2.4 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.54851320767612, -73.62365484237671) by bike: 2.2 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.50714391928411, -73.55511903762817) by bike: 7.0 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.51613214980722, -73.56049686670303) by bike: 5.0 km, Duration: 17 mins
# Distance from (45.5361062, -73.6135235) to (45.50114344835097, -73.56077313423157) by bike: 6.9 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.49837045828952, -73.56055587530136) by bike: 7.9 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.502939709023714, -73.56064036488532) by bike: 6.6 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.55358456339093, -73.6383855342865) by bike: 3.7 km, Duration: 14 mins
# Distance from (45.5361062, -73.6135235) to (45.54718706660108, -73.6184298992157) by bike: 1.9 km, Duration: 8 mins
# Distance from (45.5361062, -73.6135235) to (45.49969963056761, -73.57193648815155) by bike: 6.9 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.55331992800521, -73.56932803988457) by bike: 5.3 km, Duration: 18 mins
# Distance from (45.5361062, -73.6135235) to (45.51086, -73.54983) by bike: 6.2 km, Duration: 22 mins
# Distance from (45.5361062, -73.6135235) to (45.50424245563397, -73.553469479084) by bike: 7.0 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.557568, -73.579191) by bike: 4.4 km, Duration: 18 mins
# Distance from (45.5361062, -73.6135235) to (45.48918571608228, -73.57190027832984) by bike: 10.2 km, Duration: 35 mins
# Distance from (45.5361062, -73.6135235) to (45.48752158511353, -73.56500297784805) by bike: 9.5 km, Duration: 33 mins
# Distance from (45.5361062, -73.6135235) to (45.51025293429709, -73.55677664279938) by bike: 6.0 km, Duration: 21 mins
# Distance from (45.5361062, -73.6135235) to (45.50761009451047, -73.55183601379395) by bike: 6.6 km, Duration: 23 mins
# Distance from (45.5361062, -73.6135235) to (45.495369835210354, -73.56859177350998) by bike: 7.5 km, Duration: 28 mins
# Distance from (45.5361062, -73.6135235) to (45.491366875439965, -73.57010722160338) by bike: 8.1 km, Duration: 33 mins
# Distance from (45.5361062, -73.6135235) to (45.4891, -73.57656) by bike: 8.4 km, Duration: 32 mins
# Distance from (45.5361062, -73.6135235) to (45.52423612093815, -73.58155220746994) by bike: 3.1 km, Duration: 11 mins
# Distance from (45.5361062, -73.6135235) to (45.527070404438426, -73.59791234135628) by bike: 2.6 km, Duration: 9 mins
# Distance from (45.5361062, -73.6135235) to (45.49544692088696, -73.56329441070557) by bike: 7.6 km, Duration: 28 mins
# Distance from (45.5361062, -73.6135235) to (45.48049514330605, -73.57782661914825) by bike: 11.1 km, Duration: 39 mins
# Distance from (45.5361062, -73.6135235) to (45.48504797982277, -73.5719633102417) by bike: 10.6 km, Duration: 37 mins
# Distance from (45.5361062, -73.6135235) to (45.49750375338383, -73.55284452438353) by bike: 7.7 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.49276061084002, -73.55641052126883) by bike: 8.5 km, Duration: 30 mins
# Distance from (45.5361062, -73.6135235) to (45.49716534003792, -73.55933010578154) by bike: 7.4 km, Duration: 28 mins
# Distance from (45.5361062, -73.6135235) to (45.48972725318433, -73.56406286358833) by bike: 9.5 km, Duration: 32 mins
# Distance from (45.5361062, -73.6135235) to (45.51522812881499, -73.5750961303711) by bike: 4.4 km, Duration: 15 mins
# Distance from (45.5361062, -73.6135235) to (45.52719536319051, -73.5645255446434) by bike: 4.9 km, Duration: 16 mins
# Distance from (45.5361062, -73.6135235) to (45.48952522221574, -73.5844581949641) by bike: 8.2 km, Duration: 34 mins
# Distance from (45.5361062, -73.6135235) to (45.50788520688478, -73.56315059590997) by bike: 5.8 km, Duration: 21 mins
# Distance from (45.5361062, -73.6135235) to (45.49649602765373, -73.57870370149612) by bike: 7.1 km, Duration: 27 mins
# Distance from (45.5361062, -73.6135235) to (45.52933653055564, -73.57795268297195) by bike: 3.6 km, Duration: 12 mins
# Distance from (45.5361062, -73.6135235) to (45.53029763358792, -73.60139787197113) by bike: 1.4 km, Duration: 5 mins
# Distance from (45.5361062, -73.6135235) to (45.50370387789841, -73.56941521167755) by bike: 6.7 km, Duration: 25 mins
# Distance from (45.5361062, -73.6135235) to (45.497795545133336, -73.56825113296509) by bike: 7.5 km, Duration: 30 mins
# Distance from (45.5361062, -73.6135235) to (45.544290485374304, -73.54523241519928) by bike: 7.1 km, Duration: 27 mins
# Distance from (45.498627, -73.5709641) to (45.516926210319546, -73.56425732374191) by bike: 3.1 km, Duration: 14 mins
# Distance from (45.498627, -73.5709641) to (45.55321884238814, -73.53978216648102) by bike: 8.2 km, Duration: 34 mins
# Distance from (45.498627, -73.5709641) to (45.52689, -73.57264) by bike: 4.4 km, Duration: 19 mins
# Distance from (45.498627, -73.5709641) to (45.5534000891078, -73.66225451231003) by bike: 11.6 km, Duration: 46 mins
# Distance from (45.498627, -73.5709641) to (45.55984236120471, -73.61544728279114) by bike: 10.7 km, Duration: 46 mins
# Distance from (45.498627, -73.5709641) to (45.5457759528664, -73.56217458844185) by bike: 6.8 km, Duration: 30 mins
# Distance from (45.498627, -73.5709641) to (45.55988367688166, -73.63356828689575) by bike: 11.0 km, Duration: 44 mins
# Distance from (45.498627, -73.5709641) to (45.5616903, -73.610512) by bike: 11.0 km, Duration: 46 mins
# Distance from (45.498627, -73.5709641) to (45.53830765459552, -73.6548838019371) by bike: 11.6 km, Duration: 45 mins
# Distance from (45.498627, -73.5709641) to (45.55675103297278, -73.66716161370277) by bike: 12.3 km, Duration: 48 mins
# Distance from (45.498627, -73.5709641) to (45.52783154456306, -73.5719096660614) by bike: 4.6 km, Duration: 20 mins
# Distance from (45.498627, -73.5709641) to (45.53519006163501, -73.61548215150833) by bike: 7.6 km, Duration: 32 mins
# Distance from (45.498627, -73.5709641) to (45.53330725719417, -73.62082242965698) by bike: 7.6 km, Duration: 33 mins
# Distance from (45.498627, -73.5709641) to (45.51689731423111, -73.58910799026489) by bike: 3.6 km, Duration: 19 mins
# Distance from (45.498627, -73.5709641) to (45.51586835126322, -73.56008380651474) by bike: 2.9 km, Duration: 13 mins
# Distance from (45.498627, -73.5709641) to (45.55969734528566, -73.60145956277847) by bike: 11.1 km, Duration: 45 mins
# Distance from (45.498627, -73.5709641) to (45.55463653358596, -73.61255215771962) by bike: 9.9 km, Duration: 41 mins
# Distance from (45.498627, -73.5709641) to (45.55774990838239, -73.58380123972893) by bike: 9.6 km, Duration: 41 mins
# Distance from (45.498627, -73.5709641) to (45.54365380040509, -73.55942063033581) by bike: 7.1 km, Duration: 30 mins
# Distance from (45.498627, -73.5709641) to (45.54710313981358, -73.54892447590828) by bike: 7.2 km, Duration: 31 mins
# Distance from (45.498627, -73.5709641) to (45.51601387670667, -73.56291957199574) by bike: 3.0 km, Duration: 13 mins
# Distance from (45.498627, -73.5709641) to (45.529668174024685, -73.60166944563389) by bike: 6.1 km, Duration: 30 mins
# Distance from (45.498627, -73.5709641) to (45.55970526805903, -73.55155438184738) by bike: 10.3 km, Duration: 41 mins
# Distance from (45.498627, -73.5709641) to (45.53946063965585, -73.57605636119843) by bike: 6.5 km, Duration: 29 mins
# Distance from (45.498627, -73.5709641) to (45.5121682576952, -73.55481594800949) by bike: 4.1 km, Duration: 15 mins
# Distance from (45.498627, -73.5709641) to (45.526991277453526, -73.55821162462234) by bike: 4.6 km, Duration: 20 mins
# Distance from (45.498627, -73.5709641) to (45.52097057660443, -73.5499919950962) by bike: 3.1 km, Duration: 13 mins
# Distance from (45.498627, -73.5709641) to (45.50206, -73.56295) by bike: 1.5 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.50038, -73.57507) by bike: 0.7 km, Duration: 3 mins
# Distance from (45.498627, -73.5709641) to (45.50631445605528, -73.55967122894072) by bike: 1.6 km, Duration: 8 mins
# Distance from (45.498627, -73.5709641) to (45.50928678961862, -73.57101917266846) by bike: 2.0 km, Duration: 10 mins
# Distance from (45.498627, -73.5709641) to (45.52723106564012, -73.58672618865965) by bike: 5.1 km, Duration: 22 mins
# Distance from (45.498627, -73.5709641) to (45.53370598779895, -73.55217933654784) by bike: 5.4 km, Duration: 24 mins
# Distance from (45.498627, -73.5709641) to (45.51941, -73.58685) by bike: 3.8 km, Duration: 20 mins
# Distance from (45.498627, -73.5709641) to (45.53613488953656, -73.62258464097977) by bike: 8.3 km, Duration: 36 mins
# Distance from (45.498627, -73.5709641) to (45.53035130173597, -73.6243924498558) by bike: 8.1 km, Duration: 35 mins
# Distance from (45.498627, -73.5709641) to (45.51862424058306, -73.55219006538391) by bike: 2.8 km, Duration: 12 mins
# Distance from (45.498627, -73.5709641) to (45.55873962047568, -73.60589044634253) by bike: 10.5 km, Duration: 43 mins
# Distance from (45.498627, -73.5709641) to (45.49047561880464, -73.56022328138351) by bike: 1.6 km, Duration: 6 mins
# Distance from (45.498627, -73.5709641) to (45.485328993998365, -73.57692271471024) by bike: 2.3 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.48295816149219, -73.57975836854166) by bike: 2.6 km, Duration: 10 mins
# Distance from (45.498627, -73.5709641) to (45.55437339981968, -73.55137467384337) by bike: 8.4 km, Duration: 36 mins
# Distance from (45.498627, -73.5709641) to (45.52551168509886, -73.57424452900887) by bike: 4.4 km, Duration: 19 mins
# Distance from (45.498627, -73.5709641) to (45.55671730558936, -73.53024959564209) by bike: 8.5 km, Duration: 34 mins
# Distance from (45.498627, -73.5709641) to (45.51989655507833, -73.58010649681091) by bike: 3.8 km, Duration: 19 mins
# Distance from (45.498627, -73.5709641) to (45.48378886396517, -73.5750612616539) by bike: 2.4 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.52357479400008, -73.62344294786453) by bike: 8.0 km, Duration: 35 mins
# Distance from (45.498627, -73.5709641) to (45.54640752148169, -73.63842844963074) by bike: 9.6 km, Duration: 40 mins
# Distance from (45.498627, -73.5709641) to (45.54218173507584, -73.62268656492233) by bike: 8.3 km, Duration: 36 mins
# Distance from (45.498627, -73.5709641) to (45.52275023118295, -73.57724860310555) by bike: 4.1 km, Duration: 19 mins
# Distance from (45.498627, -73.5709641) to (45.55069206841976, -73.65636706352234) by bike: 11.2 km, Duration: 45 mins
# Distance from (45.498627, -73.5709641) to (45.540105018786974, -73.65347027778625) by bike: 11.8 km, Duration: 46 mins
# Distance from (45.498627, -73.5709641) to (45.54407915308118, -73.66735741496086) by bike: 12.7 km, Duration: 51 mins
# Distance from (45.498627, -73.5709641) to (45.51814312154928, -73.56800436973572) by bike: 3.3 km, Duration: 17 mins
# Distance from (45.498627, -73.5709641) to (45.48020822800015, -73.57759863138199) by bike: 3.8 km, Duration: 13 mins
# Distance from (45.498627, -73.5709641) to (45.51074821798916, -73.56512099504471) by bike: 2.2 km, Duration: 10 mins
# Distance from (45.498627, -73.5709641) to (45.55903106539297, -73.54830354452133) by bike: 9.9 km, Duration: 40 mins
# Distance from (45.498627, -73.5709641) to (45.51329411414168, -73.55057805776596) by bike: 4.0 km, Duration: 14 mins
# Distance from (45.498627, -73.5709641) to (45.52714838624861, -73.58947947621346) by bike: 5.1 km, Duration: 23 mins
# Distance from (45.498627, -73.5709641) to (45.53006276144042, -73.54559183120728) by bike: 4.9 km, Duration: 22 mins
# Distance from (45.498627, -73.5709641) to (45.545350334193245, -73.61032962799072) by bike: 8.6 km, Duration: 36 mins
# Distance from (45.498627, -73.5709641) to (45.50229349416256, -73.5733064264059) by bike: 0.9 km, Duration: 5 mins
# Distance from (45.498627, -73.5709641) to (45.527371996141, -73.60398352146149) by bike: 5.4 km, Duration: 26 mins
# Distance from (45.498627, -73.5709641) to (45.55398156058887, -73.55496388156098) by bike: 7.8 km, Duration: 34 mins
# Distance from (45.498627, -73.5709641) to (45.5021829099012, -73.56825381517409) by bike: 1.2 km, Duration: 5 mins
# Distance from (45.498627, -73.5709641) to (45.55315915057821, -73.53263273835182) by bike: 8.1 km, Duration: 33 mins
# Distance from (45.498627, -73.5709641) to (45.5238445756922, -73.55236601831166) by bike: 4.0 km, Duration: 17 mins
# Distance from (45.498627, -73.5709641) to (45.49572236030835, -73.55461344122887) by bike: 2.1 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.54902230455398, -73.59198164194822) by bike: 8.5 km, Duration: 38 mins
# Distance from (45.498627, -73.5709641) to (45.539306918976, -73.59521873295307) by bike: 7.1 km, Duration: 31 mins
# Distance from (45.498627, -73.5709641) to (45.48830194643546, -73.56871783733366) by bike: 1.7 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.533313304815366, -73.56671154499054) by bike: 5.2 km, Duration: 23 mins
# Distance from (45.498627, -73.5709641) to (45.52794135176983, -73.62388551235199) by bike: 7.8 km, Duration: 35 mins
# Distance from (45.498627, -73.5709641) to (45.46976497412213, -73.58923405408859) by bike: 5.1 km, Duration: 17 mins
# Distance from (45.498627, -73.5709641) to (45.54714142711512, -73.54339510202408) by bike: 7.5 km, Duration: 30 mins
# Distance from (45.498627, -73.5709641) to (45.51433912935237, -73.56168508529663) by bike: 2.7 km, Duration: 12 mins
# Distance from (45.498627, -73.5709641) to (45.55897660298603, -73.59951764345168) by bike: 10.1 km, Duration: 43 mins
# Distance from (45.498627, -73.5709641) to (45.53280412806031, -73.57190161943436) by bike: 5.3 km, Duration: 23 mins
# Distance from (45.498627, -73.5709641) to (45.53255611409675, -73.58993947505951) by bike: 6.0 km, Duration: 26 mins
# Distance from (45.498627, -73.5709641) to (45.55458281524975, -73.59631910920143) by bike: 9.4 km, Duration: 40 mins
# Distance from (45.498627, -73.5709641) to (45.52164617544124, -73.59366774559021) by bike: 4.5 km, Duration: 24 mins
# Distance from (45.498627, -73.5709641) to (45.54434593245247, -73.57697686180472) by bike: 7.1 km, Duration: 32 mins
# Distance from (45.498627, -73.5709641) to (45.541602844435374, -73.56496073305605) by bike: 6.5 km, Duration: 29 mins
# Distance from (45.498627, -73.5709641) to (45.521564270906616, -73.57036739587784) by bike: 3.7 km, Duration: 17 mins
# Distance from (45.498627, -73.5709641) to (45.4912258547597, -73.58763009309769) by bike: 2.0 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.49658063218649, -73.5762146115303) by bike: 0.7 km, Duration: 2 mins
# Distance from (45.498627, -73.5709641) to (45.49487159597493, -73.57112377882004) by bike: 0.6 km, Duration: 3 mins
# Distance from (45.498627, -73.5709641) to (45.49228068089086, -73.58096480369566) by bike: 1.6 km, Duration: 8 mins
# Distance from (45.498627, -73.5709641) to (45.50531166520915, -73.56089115142822) by bike: 1.7 km, Duration: 8 mins
# Distance from (45.498627, -73.5709641) to (45.56221872617909, -73.54626774787903) by bike: 10.0 km, Duration: 41 mins
# Distance from (45.498627, -73.5709641) to (45.49790394592446, -73.57077571808077) by bike: 81 m, Duration: 1 min
# Distance from (45.498627, -73.5709641) to (45.505173440423306, -73.5706517100334) by bike: 1.3 km, Duration: 6 mins
# Distance from (45.498627, -73.5709641) to (45.50538591756765, -73.5704317688942) by bike: 1.4 km, Duration: 6 mins
# Distance from (45.498627, -73.5709641) to (45.51401222645779, -73.56598667800426) by bike: 2.4 km, Duration: 11 mins
# Distance from (45.498627, -73.5709641) to (45.54699194653282, -73.55115339159964) by bike: 7.3 km, Duration: 30 mins
# Distance from (45.498627, -73.5709641) to (45.4912954250061, -73.56159925460815) by bike: 1.5 km, Duration: 6 mins
# Distance from (45.498627, -73.5709641) to (45.51487490356938, -73.58486406505108) by bike: 3.1 km, Duration: 17 mins
# Distance from (45.498627, -73.5709641) to (45.51059890498207, -73.56692545115948) by bike: 2.0 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.472636238971525, -73.58546018600464) by bike: 4.6 km, Duration: 15 mins
# Distance from (45.498627, -73.5709641) to (45.4801160762769, -73.58560770750046) by bike: 3.4 km, Duration: 12 mins
# Distance from (45.498627, -73.5709641) to (45.50238607958335, -73.57333794236183) by bike: 1.0 km, Duration: 5 mins
# Distance from (45.498627, -73.5709641) to (45.502053864057466, -73.57346534729004) by bike: 0.9 km, Duration: 4 mins
# Distance from (45.498627, -73.5709641) to (45.512903912221326, -73.57059180741999) by bike: 2.5 km, Duration: 13 mins
# Distance from (45.498627, -73.5709641) to (45.50277615861811, -73.57589408755302) by bike: 1.2 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.50710632433956, -73.56861054897308) by bike: 1.6 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.498488900657, -73.57436656951904) by bike: 0.4 km, Duration: 2 mins
# Distance from (45.498627, -73.5709641) to (45.49291337906463, -73.5646878182888) by bike: 1.4 km, Duration: 6 mins
# Distance from (45.498627, -73.5709641) to (45.5063713381299, -73.5642009973526) by bike: 1.2 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.501187681489775, -73.57045487814501) by bike: 0.9 km, Duration: 4 mins
# Distance from (45.498627, -73.5709641) to (45.46766565386597, -73.59391784324544) by bike: 5.5 km, Duration: 18 mins
# Distance from (45.498627, -73.5709641) to (45.53102667048665, -73.59862312674522) by bike: 5.9 km, Duration: 26 mins
# Distance from (45.498627, -73.5709641) to (45.551961779348346, -73.6303174495697) by bike: 9.8 km, Duration: 41 mins
# Distance from (45.498627, -73.5709641) to (45.53857953787113, -73.58848571777344) by bike: 7.3 km, Duration: 30 mins
# Distance from (45.498627, -73.5709641) to (45.53579541676834, -73.55795860291892) by bike: 5.9 km, Duration: 25 mins
# Distance from (45.498627, -73.5709641) to (45.52571087285848, -73.58128398656845) by bike: 4.5 km, Duration: 20 mins
# Distance from (45.498627, -73.5709641) to (45.54144823434163, -73.59839379787445) by bike: 8.1 km, Duration: 34 mins
# Distance from (45.498627, -73.5709641) to (45.52797141659334, -73.54948371648788) by bike: 4.4 km, Duration: 19 mins
# Distance from (45.498627, -73.5709641) to (45.56157008176612, -73.65338176488876) by bike: 12.2 km, Duration: 48 mins
# Distance from (45.498627, -73.5709641) to (45.54612833838664, -73.64650368695946) by bike: 10.4 km, Duration: 43 mins
# Distance from (45.498627, -73.5709641) to (45.56001959585449, -73.534934520776) by bike: 9.2 km, Duration: 36 mins
# Distance from (45.498627, -73.5709641) to (45.49996470926352, -73.55615437030792) by bike: 2.6 km, Duration: 10 mins
# Distance from (45.498627, -73.5709641) to (45.529996997063385, -73.63287091255188) by bike: 8.6 km, Duration: 37 mins
# Distance from (45.498627, -73.5709641) to (45.54851320767612, -73.62365484237671) by bike: 9.2 km, Duration: 38 mins
# Distance from (45.498627, -73.5709641) to (45.50714391928411, -73.55511903762817) by bike: 3.3 km, Duration: 14 mins
# Distance from (45.498627, -73.5709641) to (45.51613214980722, -73.56049686670303) by bike: 2.9 km, Duration: 14 mins
# Distance from (45.498627, -73.5709641) to (45.50114344835097, -73.56077313423157) by bike: 1.3 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.49837045828952, -73.56055587530136) by bike: 3.0 km, Duration: 11 mins
# Distance from (45.498627, -73.5709641) to (45.502939709023714, -73.56064036488532) by bike: 1.4 km, Duration: 8 mins
# Distance from (45.498627, -73.5709641) to (45.55358456339093, -73.6383855342865) by bike: 10.7 km, Duration: 43 mins
# Distance from (45.498627, -73.5709641) to (45.54718706660108, -73.6184298992157) by bike: 8.8 km, Duration: 37 mins
# Distance from (45.498627, -73.5709641) to (45.49969963056761, -73.57193648815155) by bike: 0.7 km, Duration: 3 mins
# Distance from (45.498627, -73.5709641) to (45.55331992800521, -73.56932803988457) by bike: 8.3 km, Duration: 36 mins
# Distance from (45.498627, -73.5709641) to (45.51086, -73.54983) by bike: 3.7 km, Duration: 13 mins
# Distance from (45.498627, -73.5709641) to (45.50424245563397, -73.553469479084) by bike: 2.9 km, Duration: 11 mins
# Distance from (45.498627, -73.5709641) to (45.557568, -73.579191) by bike: 9.3 km, Duration: 41 mins
# Distance from (45.498627, -73.5709641) to (45.48918571608228, -73.57190027832984) by bike: 1.8 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.48752158511353, -73.56500297784805) by bike: 1.9 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.51025293429709, -73.55677664279938) by bike: 2.1 km, Duration: 10 mins
# Distance from (45.498627, -73.5709641) to (45.50761009451047, -73.55183601379395) by bike: 3.3 km, Duration: 12 mins
# Distance from (45.498627, -73.5709641) to (45.495369835210354, -73.56859177350998) by bike: 0.7 km, Duration: 3 mins
# Distance from (45.498627, -73.5709641) to (45.491366875439965, -73.57010722160338) by bike: 1.2 km, Duration: 6 mins
# Distance from (45.498627, -73.5709641) to (45.4891, -73.57656) by bike: 1.4 km, Duration: 5 mins
# Distance from (45.498627, -73.5709641) to (45.52423612093815, -73.58155220746994) by bike: 4.6 km, Duration: 20 mins
# Distance from (45.498627, -73.5709641) to (45.527070404438426, -73.59791234135628) by bike: 5.2 km, Duration: 27 mins
# Distance from (45.498627, -73.5709641) to (45.49544692088696, -73.56329441070557) by bike: 0.8 km, Duration: 4 mins
# Distance from (45.498627, -73.5709641) to (45.48049514330605, -73.57782661914825) by bike: 2.9 km, Duration: 11 mins
# Distance from (45.498627, -73.5709641) to (45.48504797982277, -73.5719633102417) by bike: 2.2 km, Duration: 8 mins
# Distance from (45.498627, -73.5709641) to (45.49750375338383, -73.55284452438353) by bike: 2.1 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.49276061084002, -73.55641052126883) by bike: 1.4 km, Duration: 6 mins
# Distance from (45.498627, -73.5709641) to (45.49716534003792, -73.55933010578154) by bike: 1.9 km, Duration: 8 mins
# Distance from (45.498627, -73.5709641) to (45.48972725318433, -73.56406286358833) by bike: 1.7 km, Duration: 7 mins
# Distance from (45.498627, -73.5709641) to (45.51522812881499, -73.5750961303711) by bike: 2.9 km, Duration: 14 mins
# Distance from (45.498627, -73.5709641) to (45.52719536319051, -73.5645255446434) by bike: 4.2 km, Duration: 19 mins
# Distance from (45.498627, -73.5709641) to (45.48952522221574, -73.5844581949641) by bike: 1.7 km, Duration: 8 mins
# Distance from (45.498627, -73.5709641) to (45.50788520688478, -73.56315059590997) by bike: 2.3 km, Duration: 9 mins
# Distance from (45.498627, -73.5709641) to (45.49649602765373, -73.57870370149612) by bike: 1.0 km, Duration: 5 mins
# Distance from (45.498627, -73.5709641) to (45.52933653055564, -73.57795268297195) by bike: 5.0 km, Duration: 22 mins
# Distance from (45.498627, -73.5709641) to (45.53029763358792, -73.60139787197113) by bike: 6.5 km, Duration: 29 mins
# Distance from (45.498627, -73.5709641) to (45.50370387789841, -73.56941521167755) by bike: 1.1 km, Duration: 5 mins
# Distance from (45.498627, -73.5709641) to (45.497795545133336, -73.56825113296509) by bike: 1.0 km, Duration: 5 mins
# Distance from (45.498627, -73.5709641) to (45.544290485374304, -73.54523241519928) by bike: 7.1 km, Duration: 29 mins
# Distance from (45.501355, -73.570814) to (45.516926210319546, -73.56425732374191) by bike: 2.4 km, Duration: 11 mins
# Distance from (45.501355, -73.570814) to (45.55321884238814, -73.53978216648102) by bike: 7.5 km, Duration: 31 mins
# Distance from (45.501355, -73.570814) to (45.52689, -73.57264) by bike: 3.7 km, Duration: 16 mins
# Distance from (45.501355, -73.570814) to (45.5534000891078, -73.66225451231003) by bike: 10.9 km, Duration: 42 mins
# Distance from (45.501355, -73.570814) to (45.55984236120471, -73.61544728279114) by bike: 10.0 km, Duration: 42 mins
# Distance from (45.501355, -73.570814) to (45.5457759528664, -73.56217458844185) by bike: 6.1 km, Duration: 27 mins
# Distance from (45.501355, -73.570814) to (45.55988367688166, -73.63356828689575) by bike: 10.3 km, Duration: 41 mins
# Distance from (45.501355, -73.570814) to (45.5616903, -73.610512) by bike: 10.3 km, Duration: 43 mins
# Distance from (45.501355, -73.570814) to (45.53830765459552, -73.6548838019371) by bike: 10.9 km, Duration: 41 mins
# Distance from (45.501355, -73.570814) to (45.55675103297278, -73.66716161370277) by bike: 11.6 km, Duration: 44 mins
# Distance from (45.501355, -73.570814) to (45.52783154456306, -73.5719096660614) by bike: 3.9 km, Duration: 17 mins
# Distance from (45.501355, -73.570814) to (45.53519006163501, -73.61548215150833) by bike: 6.9 km, Duration: 28 mins
# Distance from (45.501355, -73.570814) to (45.53330725719417, -73.62082242965698) by bike: 6.9 km, Duration: 30 mins
# Distance from (45.501355, -73.570814) to (45.51689731423111, -73.58910799026489) by bike: 2.9 km, Duration: 16 mins
# Distance from (45.501355, -73.570814) to (45.51586835126322, -73.56008380651474) by bike: 2.2 km, Duration: 10 mins
# Distance from (45.501355, -73.570814) to (45.55969734528566, -73.60145956277847) by bike: 10.4 km, Duration: 42 mins
# Distance from (45.501355, -73.570814) to (45.55463653358596, -73.61255215771962) by bike: 9.2 km, Duration: 38 mins
# Distance from (45.501355, -73.570814) to (45.55774990838239, -73.58380123972893) by bike: 8.9 km, Duration: 37 mins
# Distance from (45.501355, -73.570814) to (45.54365380040509, -73.55942063033581) by bike: 6.4 km, Duration: 27 mins
# Distance from (45.501355, -73.570814) to (45.54710313981358, -73.54892447590828) by bike: 6.5 km, Duration: 28 mins
# Distance from (45.501355, -73.570814) to (45.51601387670667, -73.56291957199574) by bike: 2.3 km, Duration: 10 mins
# Distance from (45.501355, -73.570814) to (45.529668174024685, -73.60166944563389) by bike: 5.4 km, Duration: 26 mins
# Distance from (45.501355, -73.570814) to (45.55970526805903, -73.55155438184738) by bike: 9.6 km, Duration: 38 mins
# Distance from (45.501355, -73.570814) to (45.53946063965585, -73.57605636119843) by bike: 5.8 km, Duration: 26 mins
# Distance from (45.501355, -73.570814) to (45.5121682576952, -73.55481594800949) by bike: 2.1 km, Duration: 9 mins
# Distance from (45.501355, -73.570814) to (45.526991277453526, -73.55821162462234) by bike: 3.5 km, Duration: 14 mins
# Distance from (45.501355, -73.570814) to (45.52097057660443, -73.5499919950962) by bike: 2.9 km, Duration: 10 mins
# Distance from (45.501355, -73.570814) to (45.50206, -73.56295) by bike: 1.3 km, Duration: 4 mins
# Distance from (45.501355, -73.570814) to (45.50038, -73.57507) by bike: 0.6 km, Duration: 4 mins
# Distance from (45.501355, -73.570814) to (45.50631445605528, -73.55967122894072) by bike: 1.4 km, Duration: 5 mins
# Distance from (45.501355, -73.570814) to (45.50928678961862, -73.57101917266846) by bike: 1.3 km, Duration: 7 mins
# Distance from (45.501355, -73.570814) to (45.52723106564012, -73.58672618865965) by bike: 4.3 km, Duration: 19 mins
# Distance from (45.501355, -73.570814) to (45.53370598779895, -73.55217933654784) by bike: 4.7 km, Duration: 21 mins
# Distance from (45.501355, -73.570814) to (45.51941, -73.58685) by bike: 3.1 km, Duration: 16 mins
# Distance from (45.501355, -73.570814) to (45.53613488953656, -73.62258464097977) by bike: 7.6 km, Duration: 33 mins
# Distance from (45.501355, -73.570814) to (45.53035130173597, -73.6243924498558) by bike: 7.4 km, Duration: 31 mins
# Distance from (45.501355, -73.570814) to (45.51862424058306, -73.55219006538391) by bike: 2.6 km, Duration: 9 mins
# Distance from (45.501355, -73.570814) to (45.55873962047568, -73.60589044634253) by bike: 9.8 km, Duration: 40 mins
# Distance from (45.501355, -73.570814) to (45.49047561880464, -73.56022328138351) by bike: 2.3 km, Duration: 8 mins
# Distance from (45.501355, -73.570814) to (45.485328993998365, -73.57692271471024) by bike: 3.4 km, Duration: 11 mins
# Distance from (45.501355, -73.570814) to (45.48295816149219, -73.57975836854166) by bike: 3.7 km, Duration: 12 mins
# Distance from (45.501355, -73.570814) to (45.55437339981968, -73.55137467384337) by bike: 7.7 km, Duration: 33 mins
# Distance from (45.501355, -73.570814) to (45.52551168509886, -73.57424452900887) by bike: 3.7 km, Duration: 16 mins
# Distance from (45.501355, -73.570814) to (45.55671730558936, -73.53024959564209) by bike: 7.8 km, Duration: 31 mins
# Distance from (45.501355, -73.570814) to (45.51989655507833, -73.58010649681091) by bike: 3.1 km, Duration: 16 mins
# Distance from (45.501355, -73.570814) to (45.48378886396517, -73.5750612616539) by bike: 3.3 km, Duration: 10 mins
# Distance from (45.501355, -73.570814) to (45.52357479400008, -73.62344294786453) by bike: 7.3 km, Duration: 32 mins
# Distance from (45.501355, -73.570814) to (45.54640752148169, -73.63842844963074) by bike: 8.9 km, Duration: 36 mins
# Distance from (45.501355, -73.570814) to (45.54218173507584, -73.62268656492233) by bike: 7.6 km, Duration: 32 mins
# Distance from (45.501355, -73.570814) to (45.52275023118295, -73.57724860310555) by bike: 3.4 km, Duration: 15 mins
# Distance from (45.501355, -73.570814) to (45.55069206841976, -73.65636706352234) by bike: 10.4 km, Duration: 42 mins
# Distance from (45.501355, -73.570814) to (45.540105018786974, -73.65347027778625) by bike: 11.1 km, Duration: 42 mins
# Distance from (45.501355, -73.570814) to (45.54407915308118, -73.66735741496086) by bike: 12.0 km, Duration: 47 mins
# Distance from (45.501355, -73.570814) to (45.51814312154928, -73.56800436973572) by bike: 2.6 km, Duration: 14 mins
# Distance from (45.501355, -73.570814) to (45.48020822800015, -73.57759863138199) by bike: 4.6 km, Duration: 15 mins
# Distance from (45.501355, -73.570814) to (45.51074821798916, -73.56512099504471) by bike: 1.4 km, Duration: 7 mins
# Distance from (45.501355, -73.570814) to (45.55903106539297, -73.54830354452133) by bike: 9.2 km, Duration: 37 mins
# Distance from (45.501355, -73.570814) to (45.51329411414168, -73.55057805776596) by bike: 2.7 km, Duration: 11 mins
# Distance from (45.501355, -73.570814) to (45.52714838624861, -73.58947947621346) by bike: 4.4 km, Duration: 20 mins
# Distance from (45.501355, -73.570814) to (45.53006276144042, -73.54559183120728) by bike: 4.2 km, Duration: 19 mins
# Distance from (45.501355, -73.570814) to (45.545350334193245, -73.61032962799072) by bike: 7.9 km, Duration: 33 mins
# Distance from (45.501355, -73.570814) to (45.50229349416256, -73.5733064264059) by bike: 0.4 km, Duration: 2 mins
# Distance from (45.501355, -73.570814) to (45.527371996141, -73.60398352146149) by bike: 4.7 km, Duration: 22 mins
# Distance from (45.501355, -73.570814) to (45.55398156058887, -73.55496388156098) by bike: 7.1 km, Duration: 31 mins
# Distance from (45.501355, -73.570814) to (45.5021829099012, -73.56825381517409) by bike: 0.3 km, Duration: 1 min
# Distance from (45.501355, -73.570814) to (45.55315915057821, -73.53263273835182) by bike: 7.3 km, Duration: 29 mins
# Distance from (45.501355, -73.570814) to (45.5238445756922, -73.55236601831166) by bike: 3.3 km, Duration: 14 mins
# Distance from (45.501355, -73.570814) to (45.49572236030835, -73.55461344122887) by bike: 2.9 km, Duration: 11 mins
# Distance from (45.501355, -73.570814) to (45.54902230455398, -73.59198164194822) by bike: 7.8 km, Duration: 34 mins
# Distance from (45.501355, -73.570814) to (45.539306918976, -73.59521873295307) by bike: 6.4 km, Duration: 28 mins
# Distance from (45.501355, -73.570814) to (45.48830194643546, -73.56871783733366) by bike: 2.5 km, Duration: 8 mins
# Distance from (45.501355, -73.570814) to (45.533313304815366, -73.56671154499054) by bike: 4.5 km, Duration: 19 mins
# Distance from (45.501355, -73.570814) to (45.52794135176983, -73.62388551235199) by bike: 7.1 km, Duration: 32 mins
# Distance from (45.501355, -73.570814) to (45.46976497412213, -73.58923405408859) by bike: 5.8 km, Duration: 18 mins
# Distance from (45.501355, -73.570814) to (45.54714142711512, -73.54339510202408) by bike: 6.8 km, Duration: 27 mins
# Distance from (45.501355, -73.570814) to (45.51433912935237, -73.56168508529663) by bike: 1.9 km, Duration: 9 mins
# Distance from (45.501355, -73.570814) to (45.55897660298603, -73.59951764345168) by bike: 9.4 km, Duration: 39 mins
# Distance from (45.501355, -73.570814) to (45.53280412806031, -73.57190161943436) by bike: 4.6 km, Duration: 20 mins
# Distance from (45.501355, -73.570814) to (45.53255611409675, -73.58993947505951) by bike: 5.3 km, Duration: 23 mins
# Distance from (45.501355, -73.570814) to (45.55458281524975, -73.59631910920143) by bike: 8.7 km, Duration: 37 mins
# Distance from (45.501355, -73.570814) to (45.52164617544124, -73.59366774559021) by bike: 3.8 km, Duration: 20 mins
# Distance from (45.501355, -73.570814) to (45.54434593245247, -73.57697686180472) by bike: 6.4 km, Duration: 29 mins
# Distance from (45.501355, -73.570814) to (45.541602844435374, -73.56496073305605) by bike: 5.8 km, Duration: 26 mins
# Distance from (45.501355, -73.570814) to (45.521564270906616, -73.57036739587784) by bike: 3.0 km, Duration: 14 mins
# Distance from (45.501355, -73.570814) to (45.4912258547597, -73.58763009309769) by bike: 2.2 km, Duration: 11 mins
# Distance from (45.501355, -73.570814) to (45.49658063218649, -73.5762146115303) by bike: 1.3 km, Duration: 7 mins
# Distance from (45.501355, -73.570814) to (45.49487159597493, -73.57112377882004) by bike: 1.4 km, Duration: 6 mins
# Distance from (45.501355, -73.570814) to (45.49228068089086, -73.58096480369566) by bike: 1.9 km, Duration: 10 mins
# Distance from (45.501355, -73.570814) to (45.50531166520915, -73.56089115142822) by bike: 1.5 km, Duration: 5 mins
# Distance from (45.501355, -73.570814) to (45.56221872617909, -73.54626774787903) by bike: 9.3 km, Duration: 38 mins
# Distance from (45.501355, -73.570814) to (45.49790394592446, -73.57077571808077) by bike: 0.9 km, Duration: 5 mins
# ...
# Distance from (45.496652, -73.5759009) to (45.53946063965585, -73.57605636119843) by bike: 6.4 km, Duration: 29 mins
# Distance from (45.496652, -73.5759009) to (45.5121682576952, -73.55481594800949) by bike: 4.7 km, Duration: 17 mins
# Distance from (45.496652, -73.5759009) to (45.526991277453526, -73.55821162462234) by bike: 4.5 km, Duration: 19 mins
# Distance from (45.496652, -73.5759009) to (45.52097057660443, -73.5499919950962) by bike: 4.0 km, Duration: 15 mins
# Distance from (45.496652, -73.5759009) to (45.50206, -73.56295) by bike: 2.0 km, Duration: 8 mins
# Distance from (45.496652, -73.5759009) to (45.50038, -73.57507) by bike: 0.6 km, Duration: 3 mins
# Distance from (45.496652, -73.5759009) to (45.50631445605528, -73.55967122894072) by bike: 2.5 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.50928678961862, -73.57101917266846) by bike: 1.8 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.52723106564012, -73.58672618865965) by bike: 4.9 km, Duration: 22 mins
# Distance from (45.496652, -73.5759009) to (45.53370598779895, -73.55217933654784) by bike: 5.3 km, Duration: 23 mins
# Distance from (45.496652, -73.5759009) to (45.51941, -73.58685) by bike: 3.7 km, Duration: 20 mins
# Distance from (45.496652, -73.5759009) to (45.53613488953656, -73.62258464097977) by bike: 8.2 km, Duration: 36 mins
# Distance from (45.496652, -73.5759009) to (45.53035130173597, -73.6243924498558) by bike: 8.0 km, Duration: 34 mins
# Distance from (45.496652, -73.5759009) to (45.51862424058306, -73.55219006538391) by bike: 3.7 km, Duration: 15 mins
# Distance from (45.496652, -73.5759009) to (45.55873962047568, -73.60589044634253) by bike: 10.4 km, Duration: 43 mins
# Distance from (45.496652, -73.5759009) to (45.49047561880464, -73.56022328138351) by bike: 1.6 km, Duration: 7 mins
# Distance from (45.496652, -73.5759009) to (45.485328993998365, -73.57692271471024) by bike: 2.5 km, Duration: 9 mins
# Distance from (45.496652, -73.5759009) to (45.48295816149219, -73.57975836854166) by bike: 2.8 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.55437339981968, -73.55137467384337) by bike: 8.3 km, Duration: 35 mins
# Distance from (45.496652, -73.5759009) to (45.52551168509886, -73.57424452900887) by bike: 4.2 km, Duration: 19 mins
# Distance from (45.496652, -73.5759009) to (45.55671730558936, -73.53024959564209) by bike: 8.4 km, Duration: 33 mins
# Distance from (45.496652, -73.5759009) to (45.51989655507833, -73.58010649681091) by bike: 3.7 km, Duration: 19 mins
# Distance from (45.496652, -73.5759009) to (45.48378886396517, -73.5750612616539) by bike: 2.6 km, Duration: 9 mins
# Distance from (45.496652, -73.5759009) to (45.52357479400008, -73.62344294786453) by bike: 7.8 km, Duration: 35 mins
# Distance from (45.496652, -73.5759009) to (45.54640752148169, -73.63842844963074) by bike: 9.5 km, Duration: 39 mins
# Distance from (45.496652, -73.5759009) to (45.54218173507584, -73.62268656492233) by bike: 8.2 km, Duration: 35 mins
# Distance from (45.496652, -73.5759009) to (45.52275023118295, -73.57724860310555) by bike: 4.0 km, Duration: 18 mins
# Distance from (45.496652, -73.5759009) to (45.55069206841976, -73.65636706352234) by bike: 11.0 km, Duration: 45 mins
# Distance from (45.496652, -73.5759009) to (45.540105018786974, -73.65347027778625) by bike: 10.7 km, Duration: 44 mins
# Distance from (45.496652, -73.5759009) to (45.54407915308118, -73.66735741496086) by bike: 12.6 km, Duration: 50 mins
# Distance from (45.496652, -73.5759009) to (45.51814312154928, -73.56800436973572) by bike: 3.2 km, Duration: 16 mins
# Distance from (45.496652, -73.5759009) to (45.48020822800015, -73.57759863138199) by bike: 4.4 km, Duration: 15 mins
# Distance from (45.496652, -73.5759009) to (45.51074821798916, -73.56512099504471) by bike: 2.0 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.55903106539297, -73.54830354452133) by bike: 9.8 km, Duration: 39 mins
# Distance from (45.496652, -73.5759009) to (45.51329411414168, -73.55057805776596) by bike: 4.6 km, Duration: 16 mins
# Distance from (45.496652, -73.5759009) to (45.52714838624861, -73.58947947621346) by bike: 4.9 km, Duration: 23 mins
# Distance from (45.496652, -73.5759009) to (45.53006276144042, -73.54559183120728) by bike: 4.8 km, Duration: 21 mins
# Distance from (45.496652, -73.5759009) to (45.545350334193245, -73.61032962799072) by bike: 8.5 km, Duration: 36 mins
# Distance from (45.496652, -73.5759009) to (45.50229349416256, -73.5733064264059) by bike: 0.8 km, Duration: 4 mins
# Distance from (45.496652, -73.5759009) to (45.527371996141, -73.60398352146149) by bike: 5.3 km, Duration: 26 mins
# Distance from (45.496652, -73.5759009) to (45.55398156058887, -73.55496388156098) by bike: 7.7 km, Duration: 34 mins
# Distance from (45.496652, -73.5759009) to (45.5021829099012, -73.56825381517409) by bike: 1.0 km, Duration: 4 mins
# Distance from (45.496652, -73.5759009) to (45.55315915057821, -73.53263273835182) by bike: 7.9 km, Duration: 32 mins
# Distance from (45.496652, -73.5759009) to (45.5238445756922, -73.55236601831166) by bike: 3.9 km, Duration: 16 mins
# Distance from (45.496652, -73.5759009) to (45.49572236030835, -73.55461344122887) by bike: 2.7 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.54902230455398, -73.59198164194822) by bike: 8.4 km, Duration: 37 mins
# Distance from (45.496652, -73.5759009) to (45.539306918976, -73.59521873295307) by bike: 7.0 km, Duration: 31 mins
# Distance from (45.496652, -73.5759009) to (45.48830194643546, -73.56871783733366) by bike: 1.7 km, Duration: 7 mins
# Distance from (45.496652, -73.5759009) to (45.533313304815366, -73.56671154499054) by bike: 5.1 km, Duration: 22 mins
# Distance from (45.496652, -73.5759009) to (45.52794135176983, -73.62388551235199) by bike: 7.7 km, Duration: 35 mins
# Distance from (45.496652, -73.5759009) to (45.46976497412213, -73.58923405408859) by bike: 5.6 km, Duration: 18 mins
# Distance from (45.496652, -73.5759009) to (45.54714142711512, -73.54339510202408) by bike: 7.4 km, Duration: 30 mins
# Distance from (45.496652, -73.5759009) to (45.51433912935237, -73.56168508529663) by bike: 2.5 km, Duration: 12 mins
# Distance from (45.496652, -73.5759009) to (45.55897660298603, -73.59951764345168) by bike: 10.0 km, Duration: 42 mins
# Distance from (45.496652, -73.5759009) to (45.53280412806031, -73.57190161943436) by bike: 5.1 km, Duration: 23 mins
# Distance from (45.496652, -73.5759009) to (45.53255611409675, -73.58993947505951) by bike: 5.9 km, Duration: 26 mins
# Distance from (45.496652, -73.5759009) to (45.55458281524975, -73.59631910920143) by bike: 9.3 km, Duration: 40 mins
# Distance from (45.496652, -73.5759009) to (45.52164617544124, -73.59366774559021) by bike: 4.4 km, Duration: 23 mins
# Distance from (45.496652, -73.5759009) to (45.54434593245247, -73.57697686180472) by bike: 7.0 km, Duration: 31 mins
# Distance from (45.496652, -73.5759009) to (45.541602844435374, -73.56496073305605) by bike: 6.4 km, Duration: 28 mins
# Distance from (45.496652, -73.5759009) to (45.521564270906616, -73.57036739587784) by bike: 3.5 km, Duration: 16 mins
# Distance from (45.496652, -73.5759009) to (45.4912258547597, -73.58763009309769) by bike: 1.4 km, Duration: 8 mins
# Distance from (45.496652, -73.5759009) to (45.49658063218649, -73.5762146115303) by bike: 20 m, Duration: 1 min
# Distance from (45.496652, -73.5759009) to (45.49487159597493, -73.57112377882004) by bike: 0.5 km, Duration: 3 mins
# Distance from (45.496652, -73.5759009) to (45.49228068089086, -73.58096480369566) by bike: 1.0 km, Duration: 7 mins
# Distance from (45.496652, -73.5759009) to (45.50531166520915, -73.56089115142822) by bike: 2.6 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.56221872617909, -73.54626774787903) by bike: 9.9 km, Duration: 40 mins
# Distance from (45.496652, -73.5759009) to (45.49790394592446, -73.57077571808077) by bike: 0.6 km, Duration: 3 mins
# Distance from (45.496652, -73.5759009) to (45.505173440423306, -73.5706517100334) by bike: 1.2 km, Duration: 5 mins
# Distance from (45.496652, -73.5759009) to (45.50538591756765, -73.5704317688942) by bike: 1.2 km, Duration: 5 mins
# Distance from (45.496652, -73.5759009) to (45.51401222645779, -73.56598667800426) by bike: 2.3 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.54699194653282, -73.55115339159964) by bike: 7.2 km, Duration: 30 mins
# Distance from (45.496652, -73.5759009) to (45.4912954250061, -73.56159925460815) by bike: 2.1 km, Duration: 7 mins
# Distance from (45.496652, -73.5759009) to (45.51487490356938, -73.58486406505108) by bike: 2.9 km, Duration: 17 mins
# Distance from (45.496652, -73.5759009) to (45.51059890498207, -73.56692545115948) by bike: 1.9 km, Duration: 8 mins
# Distance from (45.496652, -73.5759009) to (45.472636238971525, -73.58546018600464) by bike: 5.1 km, Duration: 16 mins
# Distance from (45.496652, -73.5759009) to (45.4801160762769, -73.58560770750046) by bike: 3.6 km, Duration: 13 mins
# Distance from (45.496652, -73.5759009) to (45.50238607958335, -73.57333794236183) by bike: 0.8 km, Duration: 4 mins
# Distance from (45.496652, -73.5759009) to (45.502053864057466, -73.57346534729004) by bike: 0.8 km, Duration: 4 mins
# Distance from (45.496652, -73.5759009) to (45.512903912221326, -73.57059180741999) by bike: 2.4 km, Duration: 12 mins
# Distance from (45.496652, -73.5759009) to (45.50277615861811, -73.57589408755302) by bike: 1.0 km, Duration: 6 mins
# Distance from (45.496652, -73.5759009) to (45.50710632433956, -73.56861054897308) by bike: 1.5 km, Duration: 6 mins
# Distance from (45.496652, -73.5759009) to (45.498488900657, -73.57436656951904) by bike: 0.2 km, Duration: 1 min
# Distance from (45.496652, -73.5759009) to (45.49291337906463, -73.5646878182888) by bike: 1.1 km, Duration: 6 mins
# Distance from (45.496652, -73.5759009) to (45.5063713381299, -73.5642009973526) by bike: 1.7 km, Duration: 7 mins
# Distance from (45.496652, -73.5759009) to (45.501187681489775, -73.57045487814501) by bike: 0.8 km, Duration: 3 mins
# Distance from (45.496652, -73.5759009) to (45.46766565386597, -73.59391784324544) by bike: 6.1 km, Duration: 19 mins
# Distance from (45.496652, -73.5759009) to (45.53102667048665, -73.59862312674522) by bike: 5.8 km, Duration: 25 mins
# Distance from (45.496652, -73.5759009) to (45.551961779348346, -73.6303174495697) by bike: 9.6 km, Duration: 40 mins
# Distance from (45.496652, -73.5759009) to (45.53857953787113, -73.58848571777344) by bike: 7.1 km, Duration: 30 mins
# Distance from (45.496652, -73.5759009) to (45.53579541676834, -73.55795860291892) by bike: 5.8 km, Duration: 25 mins
# Distance from (45.496652, -73.5759009) to (45.52571087285848, -73.58128398656845) by bike: 4.4 km, Duration: 20 mins
# Distance from (45.496652, -73.5759009) to (45.54144823434163, -73.59839379787445) by bike: 8.0 km, Duration: 34 mins
# Distance from (45.496652, -73.5759009) to (45.52797141659334, -73.54948371648788) by bike: 4.3 km, Duration: 18 mins
# Distance from (45.496652, -73.5759009) to (45.56157008176612, -73.65338176488876) by bike: 12.1 km, Duration: 48 mins
# Distance from (45.496652, -73.5759009) to (45.54612833838664, -73.64650368695946) by bike: 10.3 km, Duration: 43 mins
# Distance from (45.496652, -73.5759009) to (45.56001959585449, -73.534934520776) by bike: 9.0 km, Duration: 36 mins
# Distance from (45.496652, -73.5759009) to (45.49996470926352, -73.55615437030792) by bike: 3.1 km, Duration: 11 mins
# Distance from (45.496652, -73.5759009) to (45.529996997063385, -73.63287091255188) by bike: 8.5 km, Duration: 37 mins
# Distance from (45.496652, -73.5759009) to (45.54851320767612, -73.62365484237671) by bike: 9.1 km, Duration: 37 mins
# Distance from (45.496652, -73.5759009) to (45.50714391928411, -73.55511903762817) by bike: 3.9 km, Duration: 16 mins
# Distance from (45.496652, -73.5759009) to (45.51613214980722, -73.56049686670303) by bike: 2.7 km, Duration: 13 mins
# Distance from (45.496652, -73.5759009) to (45.50114344835097, -73.56077313423157) by bike: 1.8 km, Duration: 9 mins
# Distance from (45.496652, -73.5759009) to (45.49837045828952, -73.56055587530136) by bike: 3.6 km, Duration: 13 mins
# Distance from (45.496652, -73.5759009) to (45.502939709023714, -73.56064036488532) by bike: 1.9 km, Duration: 9 mins
# Distance from (45.496652, -73.5759009) to (45.55358456339093, -73.6383855342865) by bike: 10.5 km, Duration: 43 mins
# Distance from (45.496652, -73.5759009) to (45.54718706660108, -73.6184298992157) by bike: 8.7 km, Duration: 36 mins
# Distance from (45.496652, -73.5759009) to (45.49969963056761, -73.57193648815155) by bike: 0.8 km, Duration: 4 mins
# Distance from (45.496652, -73.5759009) to (45.55331992800521, -73.56932803988457) by bike: 8.1 km, Duration: 35 mins
# Distance from (45.496652, -73.5759009) to (45.51086, -73.54983) by bike: 4.3 km, Duration: 15 mins
# Distance from (45.496652, -73.5759009) to (45.50424245563397, -73.553469479084) by bike: 3.5 km, Duration: 12 mins
# Distance from (45.496652, -73.5759009) to (45.557568, -73.579191) by bike: 9.2 km, Duration: 40 mins
# Distance from (45.496652, -73.5759009) to (45.48918571608228, -73.57190027832984) by bike: 1.9 km, Duration: 7 mins
# Distance from (45.496652, -73.5759009) to (45.48752158511353, -73.56500297784805) by bike: 2.4 km, Duration: 8 mins
# Distance from (45.496652, -73.5759009) to (45.51025293429709, -73.55677664279938) by bike: 3.0 km, Duration: 12 mins
# Distance from (45.496652, -73.5759009) to (45.50761009451047, -73.55183601379395) by bike: 3.9 km, Duration: 13 mins
# Distance from (45.496652, -73.5759009) to (45.495369835210354, -73.56859177350998) by bike: 0.8 km, Duration: 4 mins
# Distance from (45.496652, -73.5759009) to (45.491366875439965, -73.57010722160338) by bike: 1.3 km, Duration: 6 mins
# Distance from (45.496652, -73.5759009) to (45.4891, -73.57656) by bike: 1.6 km, Duration: 6 mins
# Distance from (45.496652, -73.5759009) to (45.52423612093815, -73.58155220746994) by bike: 4.4 km, Duration: 20 mins
# Distance from (45.496652, -73.5759009) to (45.527070404438426, -73.59791234135628) by bike: 5.1 km, Duration: 26 mins
# Distance from (45.496652, -73.5759009) to (45.49544692088696, -73.56329441070557) by bike: 1.4 km, Duration: 5 mins
# Distance from (45.496652, -73.5759009) to (45.48049514330605, -73.57782661914825) by bike: 3.0 km, Duration: 11 mins
# Distance from (45.496652, -73.5759009) to (45.48504797982277, -73.5719633102417) by bike: 2.3 km, Duration: 8 mins
# Distance from (45.496652, -73.5759009) to (45.49750375338383, -73.55284452438353) by bike: 2.7 km, Duration: 10 mins
# Distance from (45.496652, -73.5759009) to (45.49276061084002, -73.55641052126883) by bike: 2.0 km, Duration: 8 mins
# Distance from (45.496652, -73.5759009) to (45.49716534003792, -73.55933010578154) by bike: 1.9 km, Duration: 9 mins
# Distance from (45.496652, -73.5759009) to (45.48972725318433, -73.56406286358833) by bike: 2.3 km, Duration: 8 mins
# Distance from (45.496652, -73.5759009) to (45.51522812881499, -73.5750961303711) by bike: 2.8 km, Duration: 14 mins
# Distance from (45.496652, -73.5759009) to (45.52719536319051, -73.5645255446434) by bike: 4.1 km, Duration: 18 mins
# Distance from (45.496652, -73.5759009) to (45.48952522221574, -73.5844581949641) by bike: 1.4 km, Duration: 9 mins
# Distance from (45.496652, -73.5759009) to (45.50788520688478, -73.56315059590997) by bike: 2.2 km, Duration: 9 mins
# Distance from (45.496652, -73.5759009) to (45.49649602765373, -73.57870370149612) by bike: 0.3 km, Duration: 2 mins
# Distance from (45.496652, -73.5759009) to (45.52933653055564, -73.57795268297195) by bike: 4.8 km, Duration: 22 mins
# Distance from (45.496652, -73.5759009) to (45.53029763358792, -73.60139787197113) by bike: 6.4 km, Duration: 28 mins
# Distance from (45.496652, -73.5759009) to (45.50370387789841, -73.56941521167755) by bike: 0.9 km, Duration: 4 mins
# Distance from (45.496652, -73.5759009) to (45.497795545133336, -73.56825113296509) by bike: 1.4 km, Duration: 7 mins
# Distance from (45.496652, -73.5759009) to (45.544290485374304, -73.54523241519928) by bike: 7.0 km, Duration: 29 mins

# %%
# Load the main CSV file into a DataFrame
metro_stations_df = pd.read_csv('metro_stations.csv')

# Load the CSV file containing the column you want to add
bus_stations_df = pd.read_csv('bus_stations.csv')

# Merge the DataFrames based on the common column
merged_df = pd.merge(metro_stations_df, bus_stations_df[['Place ID', 'Bus_Stations_Count']], on='Place ID', how='left')

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('bus_metro_stations.csv', index=False)
